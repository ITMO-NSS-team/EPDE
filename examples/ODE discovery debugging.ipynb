# %% [markdown]
# # Examples of ordinary differential equation discovery with EPDE framework
#
# This notebook presents an overview of the evolutionary discovery of ODE on examples...

# %%
import numpy as np
import os
import sys
from typing import Union, Callable

import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ADD SOME LINK TO ARTICLE ON EPDE PRINCIPLES

# %%
import sys
sys.path.append('..')
import helpers

# %%
import epde

mpl.rcParams.update(mpl.rcParamsDefault)
plt.rcParams['text.usetex'] = True

SMALL_SIZE = 12
mpl.rc('font', size=SMALL_SIZE)
mpl.rc('axes', titlesize=SMALL_SIZE)

# %% [markdown]
# ## First order ODE with trigonometric functions

# %% [markdown]
# Principles of equation discovery can be illustrated by a simple example of reconstruction of first-order equation:
#
# \begin{equation}
# \label{eq:ODE1}
# x \sin{t} + \frac{d x}{d t} \cos{t} = 1,
# \end{equation}
#
# where the general solution for an arbitrary constant $C$ is:
#
# \begin{equation}
# \label{eq:ODE1_solution}
# x = \sin{t} + C \cos{t}.
# \end{equation}
#
# To generate the data we will use an analytical particular solution, matching initial condition of $x(0) = 1.3$ (thus, $C = 1.3$) on the interval of $(0, 4 \pi)$:
#
# \begin{equation}
# \label{eq:ODE1_part_solution}
# x = \sin{t} + 1.3 \cos{t}.
# \end{equation}
#
# Furthermore, we will provide an example of using a priori known derivatvies, that can be easily calculated by differentiating the solution:
#
# \begin{equation}
# \label{eq:ODE1_deriv_solution}
# x' = \cos{t} - 1.3 \sin{t}.
# \end{equation}

# %%
C = 1.3
t = np.linspace(0, 4*np.pi, 200)
x = np.sin(t) + C * np.cos(t)
x_dot = np.cos(t) - C * np.sin(t)

max_axis_idx = x.ndim - 1

plt.plot(t, x, color = 'k', label = 'x(t)')
plt.plot(t, x_dot, color = 'r', label = "x'(t)")

plt.legend(loc = 'upper right')
plt.xlabel('t')
plt.ylabel('x')
plt.show()

# %% [markdown]
# Next, we shall initialize the equation search object. Here we are using multiobjective optimization (here, it i denoted explicitly, despite it being the default option). Non-defalut parameter is the size of the boundary: $s_{bnd} = 20$.
#
# Additional parameters will be as follows  population size number of optimziation epochs: ``n_epochs = 30``.
#
# To be able to discovery the correct governing equation, the set of elementary functions (i.e. tokens) (in addition to the derivatives, that are always used) has to include the trigonometric functions. Furthermore, we will include grid as elementary block to provide diversity of the tokens.

# %%
bnd = 20
n_epochs = 60
popsize = 8

epde_search_obj = epde.EpdeSearch(multiobjective_mode = True, boundary = bnd, 
                                  dimensionality = max_axis_idx, coordinate_tensors = [t,], 
                                  verbose_params = {'show_iter_idx' : False}) # False for brevity

trig_tokens = epde.TrigonometricTokens(freq = (0.95, 1.05), dimensionality=max_axis_idx)
grid_tokens = epde.GridTokens(['x_0',], dimensionality = max_axis_idx)

epde_search_obj.set_moeadd_params(population_size = popsize, training_epochs=n_epochs)
# Out:
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7f5818e76bb0>
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7f5818e76bb0>
# trig_token_params: VALUES = (0, 0)

# %% [markdown]
# The detection of differential equations is initiated with ``EpdeSearch.fit()`` method. Data is passed in the ``data`` argument, where the elements of the argument list are numpy.ndarrays, describing individual variables. The derivatives can be passed explicity in the argument ``derivs`` with the same logic: the argument has to be a list with numpy.ndarrays of derivatives for each variable. The dimensionality of such arrays has to be $n\_points \; \times \; deriv\_ords$, where $n\_points$ is the total number of points in the domain, and $deriv\_ords$ is the number of passed derivatives. With ``derivs = None``, the derivatives are calculated numerically.
#
# Additional elementary functions, that we expect to have in the resulting equations, are passed in the ``additional_tokens`` argument.
#
# We define equation structure properties with the following settings:
#
# - Argument ``max_deriv_order`` sets the highest order of derivatives, that can be used in equation search.
# - Number of terms, accepted into the structure before regularization is regulated by argument ``equation_terms_max_number``.
# - Argument ``equation_factors_max_number`` defined number of terms in the term can be set as integer (in this case, the number of factors for the particular term is selected from a uniform distribution $U(1, equation\_factors\_max\_number)$), or by dictionary, as in our example.
# - Argument ``data_fun_pow`` indicates the highest power of derivative-like token in the equation. With ``data_fun_pow = 2``, supported by sufficiently high ``equation_factors_max_number`` and ``equation_terms_max_number``, the terms like $u^2 u'$ and $(u')^2 \cdot u^2$ can appear in the equation, while terms like $u^3$ won't be allowed in structures.
# - Sparsity constant range ``eq_sparsity_interval`` controls the complexities of the initially created candidate equations: the argument has to be a tuple of $(a_{left}, a_{right})$. Each candidate during the population initialization is given a value $\lambda = \exp{l}; \; l \sim U(\ln a_{left}, \ln a_{right})$. With the boundaries shifted to 0, the equation is regularized less, while with high values of $ a_{left} \; \& \; a_{right}$ the majority of terms will be filtered out.

# %%
factors_max_number = {'factors_num' : [1, 2], 'probas' : [0.65, 0.35]} # 1 factor with P = 0.65, 2 with P = 0.35

epde_search_obj.fit(data=[x,], variable_names=['u',], max_deriv_order=(1,), derivs=[x_dot.reshape((-1, 1)),],
                    equation_terms_max_number=4, data_fun_pow = 1,
                    additional_tokens=[trig_tokens, grid_tokens],
                    equation_factors_max_number=factors_max_number,
                    eq_sparsity_interval=(1e-6, 1e-2))
# Out:
# Deriv orders after definition [[0]]
# initial_shape (200,) derivs_tensor.shape (200, 1)
# self.tokens is ['du/dx0']
# Here, derivs order is {'du/dx0': [0]}
# self.tokens is ['u']
# Here, derivs order is {'u': [None]}
# The cardinality of defined token pool is [1 1 2 1]
# Among them, the pool contains [1 1 1]
# self.vars_demand_equation {'u'}
# Creating new equation, sparsity value [2.28860228e-05]
# self.tokens: ['du/dx0']
# self.tokens: ['x_0']
# self.tokens: ['u']
# self.tokens: ['x_0']
# self.tokens: ['sin', 'cos']
# New solution accepted, confirmed 1/8 solutions.
# Creating new equation, sparsity value [4.07397666e-05]
# self.tokens: ['du/dx0']
# self.tokens: ['x_0']
# self.tokens: ['x_0']
# self.tokens: ['x_0']
# self.tokens: ['u']
# self.tokens: ['du/dx0']
# self.tokens: ['x_0']
# New solution accepted, confirmed 2/8 solutions.
# Creating new equation, sparsity value [8.08702643e-05]
# self.tokens: ['du/dx0']
# self.tokens: ['sin', 'cos']
# self.tokens: ['du/dx0']
# self.tokens: ['u']
# self.tokens: ['du/dx0']
# self.tokens: ['x_0']
# New solution accepted, confirmed 3/8 solutions.
# Creating new equation, sparsity value [0.00024349]
# self.tokens: ['u']
# self.tokens: ['sin', 'cos']
# self.tokens: ['du/dx0']
# self.tokens: ['sin', 'cos']
# self.tokens: ['du/dx0']
# self.tokens: ['x_0']
# New solution accepted, confirmed 4/8 solutions.
# Creating new equation, sparsity value [0.00195001]
# self.tokens: ['u']
# self.tokens: ['sin', 'cos']
# self.tokens: ['du/dx0']
# self.tokens: ['sin', 'cos']
# self.tokens: ['u']
# self.tokens: ['du/dx0']
# self.tokens: ['x_0']
# New solution accepted, confirmed 5/8 solutions.
# Creating new equation, sparsity value [3.60092331e-06]
# self.tokens: ['u']
# self.tokens: ['u']
# self.tokens: ['sin', 'cos']
# self.tokens: ['u']
# self.tokens: ['du/dx0']
# self.tokens: ['sin', 'cos']
# self.tokens: ['x_0']
# New solution accepted, confirmed 6/8 solutions.
# Creating new equation, sparsity value [1.65813759e-06]
# self.tokens: ['u']
# self.tokens: ['du/dx0']
# self.tokens: ['sin', 'cos']
# self.tokens: ['du/dx0']
# self.tokens: ['sin', 'cos']
# self.tokens: ['du/dx0']
# self.tokens: ['x_0']
# self.tokens: ['sin', 'cos']
# New solution accepted, confirmed 7/8 solutions.
# Creating new equation, sparsity value [0.00905467]
# self.tokens: ['u']
# self.tokens: ['sin', 'cos']
# self.tokens: ['u']
# self.tokens: ['x_0']
# self.tokens: ['du/dx0']
# self.tokens: ['du/dx0']
# self.tokens: ['x_0']
# New solution accepted, confirmed 8/8 solutions.
# [0.58, 0.42000000000000004] [[0.74, 0.26], [0.58, 0.42000000000000004], [0.28, 0.72], [0.66, 0.33999999999999997], [1.0, 0.0]]
# best_obj 2
# self.tokens: ['du/dx0']
# self.tokens: ['du/dx0']
# self.tokens: ['du/dx0']
# self.tokens: ['u']
# self.tokens: ['du/dx0']
# self.tokens: ['du/dx0']
# self.tokens: ['u']
# self.tokens: ['u']
# An error while creating factor of poly of u token family
# Status description: {'u': [0, 1, False], 'sin': [0, 1, False], 'cos': [0, 1, False], 'x_0': [0, 1, False], 'du/dx0': [0, 1, False]}  all: ['u']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/epde/EPDE_main/epde/interface/token_family.py in create(self, label, token_status, create_derivs, **factor_params)
#     347                 if create_derivs:
# --> 348                     label = np.random.choice([token for token in self.tokens
#     349                                               if (not token_status[token][0] + 1 > token_status[token][1]
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: 'a' cannot be empty unless no samples are taken
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c51deb56de5a> in <module>
#       1 factors_max_number = {'factors_num' : [1, 2], 'probas' : [0.65, 0.35]} # 1 factor with P = 0.65, 2 with P = 0.35
#       2
# ----> 3 epde_search_obj.fit(data=[x,], variable_names=['u',], max_deriv_order=(1,), derivs=[x_dot.reshape((-1, 1)),],
#       4                     equation_terms_max_number=4, data_fun_pow = 1,
#       5                     additional_tokens=[trig_tokens, grid_tokens],
#
# ~/epde/EPDE_main/epde/interface/interface.py in fit(self, data, equation_terms_max_number, equation_factors_max_number, variable_names, eq_sparsity_interval, derivs, max_deriv_order, additional_tokens, data_fun_pow)
#     676
#     677         self.optimizer.set_strategy(self.director)
# --> 678         self.optimizer.optimize(**self.optimizer_exec_params)
#     679
#     680         print('The optimization has been conducted.')
#
# ~/epde/EPDE_main/epde/optimizers/moeadd/moeadd.py in optimize(self, epochs)
#     450                         print(f'During MO : processing {weight_idx}-th weight.')
#     451                     sp_kwargs = self.form_processer_args(weight_idx)
# --> 452                     self.sector_processer.run(population_subset = self.pareto_levels,
#     453                                               EA_kwargs = sp_kwargs)
#     454                 stats = self.pareto_levels.get_stats()
#
# ~/epde/EPDE_main/epde/optimizers/moeadd/strategy_elems.py in run(self, population_subset, EA_kwargs)
#      17     '''
#      18     def run(self, population_subset, EA_kwargs : dict):
# ---> 19         self.linked_blocks.traversal(population_subset, EA_kwargs)
#      20         return self.linked_blocks.output
#
# ~/epde/EPDE_main/epde/optimizers/blocks.py in traversal(self, input_obj, EA_kwargs)
#     199             for vertex in processed:
#     200                 if vertex.available:
# --> 201                     vertex.apply(EA_kwargs)
#     202                     processed_new.extend(vertex._outgoing)
#     203                     if vertex.terminal:
#
# ~/epde/EPDE_main/epde/optimizers/blocks.py in apply(self, EA_kwargs)
#     126         self.check_integrity()
#     127         kwargs = {kwarg_key : EA_kwargs[kwarg_key] for kwarg_key in self.arg_keys}
# --> 128         self.output = self._operator.apply(self.combinator([block.output for block in self._incoming]),
#     129                                            arguments = kwargs)
#     130         super().apply()
#
# ~/epde/EPDE_main/epde/operators/multiobjective/moeadd_specific.py in apply(self, objective, arguments)
#     352             attempt = 1; attempt_limit = self.params['attempt_limit']
#     353             while True:
# --> 354                 temp_offspring = self.suboperators['chromosome_mutation'].apply(objective = offspring,
#     355                                                                                 arguments = subop_args['chromosome_mutation'])
#     356                 self.suboperators['right_part_selector'].apply(objective = temp_offspring,
#
# ~/epde/EPDE_main/epde/operators/multiobjective/mutations.py in apply(self, objective, arguments)
#      35         if affected_by_mutation:
#      36             for eq_key in eqs_keys:
# ---> 37                 altered_eq = self.suboperators['equation_mutation'].apply(altered_objective.vals[eq_key],
#      38                                                                           subop_args['equation_mutation'])
#      39
#
# ~/epde/EPDE_main/epde/decorators.py in wrapper(obj, *args, **kwargs)
#      90                             ' || before operation: ' + element.state + ender)
#      91
# ---> 92             result = method(obj, *args, **kwargs)
#      93             if 'a' in self.state_writing_points:
#      94                 beginner = ' | ' if 'b' in self.state_writing_points else ' || '
#
# ~/epde/EPDE_main/epde/operators/multiobjective/mutations.py in apply(self, objective, arguments)
#      61         for term_idx in range(objective.n_immutable, len(objective.structure)):
#      62             if np.random.uniform(0, 1) <= self.params['r_mutation']:
# ---> 63                 objective.structure[term_idx] = self.suboperators['mutation'].apply(objective = (term_idx, objective),
#      64                                                                                     arguments = subop_args['mutation'])
#      65         return objective
#
# ~/epde/EPDE_main/epde/operators/multiobjective/mutations.py in apply(self, objective, arguments)
#     113         create_derivs = bool(objective[1].structure[objective[0]].descr_variable_marker)
#     114
# --> 115         new_term = Term(objective[1].pool, mandatory_family = objective[1].structure[objective[0]].descr_variable_marker,
#     116                         create_derivs=create_derivs,
#     117                         max_factors_in_term = objective[1].metaparameters['max_factors_in_term']['value'])
#
# ~/epde/EPDE_main/epde/structure/main_structures.py in __init__(self, pool, passed_term, mandatory_family, max_factors_in_term, create_derivs, interelement_operator, collapse_powers)
#      58
#      59         if passed_term is None:
# ---> 60             self.randomize(mandatory_family=mandatory_family,
#      61                            create_derivs=create_derivs)
#      62         else:
#
# ~/epde/EPDE_main/epde/structure/main_structures.py in randomize(self, mandatory_family, forbidden_factors, create_derivs, **kwargs)
#     172                                                           create_derivs=create_derivs, **kwargs)
#     173         else:
# --> 174             occupied_by_factor, factor = self.pool.create_with_var(variable=mandatory_family,
#     175                                                                    token_status=self.occupied_tokens_labels,
#     176                                                                    create_derivs=create_derivs,
#
# ~/epde/EPDE_main/epde/interface/token_family.py in create_with_var(self, variable, token_status, **kwargs)
#     579         probabilities = np.array([len(f.tokens) for f in families])
#     580         family = np.random.choice(families, p = probabilities/probabilities.sum())
# --> 581         return family.create(label=None, token_status=token_status, **kwargs)
#     582
#     583     def __add__(self, other):
#
# ~/epde/EPDE_main/epde/interface/token_family.py in create(self, label, token_status, create_derivs, **factor_params)
#     356                     f'An error while creating factor of {self.ftype} token family')
#     357                 print('Status description:', token_status, ' all:', self.tokens)
# --> 358                 raise ValueError("'a' cannot be empty unless no samples are taken")
#     359
#     360         if self.family_of_derivs:
#
# ValueError: 'a' cannot be empty unless no samples are taken

# %%
epde_search_obj.cache[1].memory_structural.keys()

# %% [markdown]
# The discovered equations can be accessed with ``EpdeSearch.equations()`` method. If the ``only_print = True``, than the equations will be printed in their text forms.
#
# Otherwise, they will be return: if the followup argument ``only_str`` is ``True``, than the equations are returned only in their symbolic string-form. If ``only_str = False``, than the equation in its program implementation ``epde.structure.main_structures.SoEq`` are returned.

# %%
res = epde_search_obj.equations(False)

# %%
epde_search_obj.equations(only_print=True)
# Out:
# 0-th non-dominated level
#
#
# 1.0012608846836293 * u{power: 1.0} * cos{power: 1.0, freq: 1.0052191948224247, dim: 0.0} + 0.0 * du/dx0{power: 1.0} + 0.0 * u{power: 1.0} + -1.2689480685083514 = du/dx0{power: 1.0} * sin{power: 1.0, freq: 1.0046467188854549, dim: 0.0}
# {'terms_number': {'optimizable': False, 'value': 4}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0057066461587413336}} , with objective function values of [0.12374862 2.5       ]
#
# 0.0 * x_0{power: 1.0, dim: 0.0} + 0.0 * u{power: 1.0} + -0.0051329370577846735 * u{power: 1.0} * x_0{power: 1.0, dim: 0.0} + -0.12275464904992871 = du/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 4}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.008122842263509658}} , with objective function values of [11.87817452  2.        ]
#
# 0.9998615806681939 * u{power: 1.0} * cos{power: 1.0, freq: 1.0052191948224247, dim: 0.0} + 0.0 * du/dx0{power: 1.0} + 0.005243942371150501 * x_0{power: 1.0, dim: 0.0} + -1.3010271524235102 = du/dx0{power: 1.0} * sin{power: 1.0, freq: 1.0046467188854549, dim: 0.0}
# {'terms_number': {'optimizable': False, 'value': 4}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0016572155356233435}} , with objective function values of [0.02282624 3.        ]
#
# 0.0 * x_0{power: 1.0, dim: 0.0} + -0.0051329370577846735 * u{power: 1.0} * x_0{power: 1.0, dim: 0.0} + 0.0 * u{power: 1.0} + -0.12275464904992871 = du/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 4}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.004170660778008305}} , with objective function values of [11.87817452  2.        ]

# %% [markdown]
# The particular solution of the ODE in addition to the governing equation $x \sin{(t)} + x' \cos{(t)} = 1,$ also matches the solution of equation $x' \sin{(t)}  - x \cos{(t)} = - 1.3$. With them having (in ideal case) the same fitness functions values, we can expect presence of at least one type of such results in the equation.

# %% [markdown]
# We can use visual analysis of the Pareto-optimal set of candidate equations, placed in the complexity-quality criteria space, to select the optimal equation. Method ``EpdeSearch.visualize_solutions()`` illustrates the first non-dominated set of solutions (i.e. Pareto frontier). With its help we can see, that equations like $x' \cdot \sin{(1.001 \; t)} = 9.997\cdot 10^{-1} x \cdot cos{(1.006 \; t)} + -1.274$ (may differ due to stochastic nature of evolutionary optimization) matches the knee point of a Pareto frontier curve. *Note* In some cases, only two equations are discovered, or if multiple simple equations are proposed, thus no knee point analysis.

# %%
epde_search_obj.visualize_solutions()
# Out:
# $\begin{eqnarray*} \frac{\partial u}{\partial x_0} \cdot sin^{1.0}(1.005 x_{0.0}) = 1.001u \cdot cos^{1.0}(1.005 x_{0.0}) + -1.269 \end{eqnarray*}$
# $\begin{eqnarray*} \frac{\partial u}{\partial x_0} = -5.133\cdot 10^{-3} u \cdot x_0 + -1.228\cdot 10^{-1}  \end{eqnarray*}$
# $\begin{eqnarray*} \frac{\partial u}{\partial x_0} \cdot sin^{1.0}(1.005 x_{0.0}) = 9.999\cdot 10^{-1} u \cdot cos^{1.0}(1.005 x_{0.0}) + 5.244\cdot 10^{-3} x_0 + -1.301 \end{eqnarray*}$

# %% [markdown]
# ## Second order non-linear ODE

# %% [markdown]
# A more complex example of the problem can be posed by a linear non-homogeneous equation $x'' + \sin{(2t)} x' + 4 x = 1.5 t$. To get a synthetic dataset we can solve it with Runge-Kutta fourth order method. The particular solution matches the initial problem of $x|_{t = 0} = 0.8$, $x''|_{t = 0} = 2.0$ for domain $t \in [0, 16)$.

# %%
def second_order_lODE_by_RK(initial : tuple, timestep : float, steps : int, g1 : Callable, 
                           g2 : Callable, g3 : Callable, g4 : Callable):
    res = np.full(shape = (steps, 2), fill_value = initial, dtype=np.float64)
    for step in range(steps-1):
        t = step*timestep
        k1 = res[step, 1] ; x1 = res[step, 0] + timestep/2. * k1
        l1 = (g4(t) - g3(t)*res[step, 0] - g2(t)*res[step, 1]) / g1(t); y1 = res[step, 1] + timestep/2. * l1

        k2 = y1; x2 = res[step, 0] + timestep/2. * k2
        l2 = (g4(t) - g3(t)*x1 - g2(t)*y1) / g1(t); y2 = res[step, 1] + timestep/2. * l2

        k3 = y2
        l3 = (g4(t) - g3(t)*x2 - g2(t)*y2) / g1(t);
        
        x3 = res[step, 0] + timestep * k1 - 2 * timestep * k2 + 2 * timestep * k3
        y3 = res[step, 1] + timestep * l1 - 2 * timestep * l2 + 2 * timestep * l3
        k4 = y3
        l4 = (g4(t) - g3(t)*x3 - g2(t)*y3) / g1(t)
        
        res[step+1, 0] = res[step, 0] + timestep / 6. * (k1 + 2 * k2 + 2 * k3 + k4)
        res[step+1, 1] = res[step, 1] + timestep / 6. * (l1 + 2 * l2 + 2 * l3 + l4)
    return res

# %%
g1 = lambda x: 1.
g2 = lambda x: np.sin(2*x)
g3 = lambda x: 4.
g4 = lambda x: 1.5*x

step = 0.05; steps_num = 320
t = np.arange(start = 0., stop = step * steps_num, step = step)
solution = second_order_lODE_by_RK(initial=(0.8, 2.), timestep=step, steps=steps_num, 
                                  g1=g1, g2=g2, g3=g3, g4=g4)

# %%
plt.plot(t, solution[:, 0], label = 'x(t)', color = 'limegreen')
plt.plot(t, solution[:, 1], label = "x'(t)", color = 'darkmagenta')
plt.grid(); plt.legend()
plt.xlabel('T'); plt.ylabel('variable value')
plt.show()

# %% [markdown]
# While it can be insightful to analyze the process with the data-driven differential equation, occasionally it will be needed to predict the future state of the system, based on the equation. In this experiment we will split the input dataset into train ($t \in [0, 8)$) and test ($t \in [8, 16)$) parts. To validate the predicitive ability, the best equation will be integrated over the domain, using internal automaitic differential equation solution methods.

# %%
def epde_discovery(t, x, use_ann = False):
    dimensionality = x.ndim - 1
    

    epde_search_obj = epde.EpdeSearch(use_solver = False, dimensionality = dimensionality, boundary = 30,
                                      coordinate_tensors = [t,], verbose_params = {'show_iter_idx' : False})
    if use_ann:
        epde_search_obj.set_preprocessor(default_preprocessor_type='ANN',
                                         preprocessor_kwargs={'epochs_max' : 50000})
    else:
        epde_search_obj.set_preprocessor(default_preprocessor_type='poly',
                                         preprocessor_kwargs={'use_smoothing' : False, 'sigma' : 1, 
                                                              'polynomial_window' : 3, 'poly_order' : 3}) 

    eps = 5e-7
    popsize = 10
    epde_search_obj.set_moeadd_params(population_size = popsize, training_epochs=55)
    trig_tokens = epde.TrigonometricTokens(freq = (2 - eps, 2 + eps), 
                                      dimensionality = dimensionality)
    factors_max_number = {'factors_num' : [1, 2], 'probas' : [0.65, 0.35]}

    custom_grid_tokens = epde.GridTokens(dimensionality = dimensionality)
    
    epde_search_obj.fit(data=[x,], variable_names=['u',], max_deriv_order=(2,),
                        equation_terms_max_number=6, data_fun_pow = 1, 
                        additional_tokens=[trig_tokens, custom_grid_tokens], 
                        equation_factors_max_number=factors_max_number,
                        eq_sparsity_interval=(1e-6, 1e-2))

    epde_search_obj.equations(only_print = True, num = 1)
    
    '''
    Having insight about the initial ODE structure, we are extracting the equation with complexity of 5
    
    In other cases, you should call epde_search_obj.equations(only_print = True), or epde_search_obj.
    where the algorithm presents Pareto frontier of optimal equations.
    '''

    return epde_search_obj

# %%
t_max = 160
t_train = t[:t_max]; t_test = t[t_max:] 
x_train = solution[:t_max, 0]; x_test = solution[t_max:, 0]

epde_search_obj = epde_discovery(t_train, x_train, True)
# Out:
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7f111cbb6580>
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7f111cbb6580>
# trig_token_params: VALUES = (0, 0)
# Deriv orders after definition [[0], [0, 0]]
# initial_shape (160,) derivs_tensor.shape (160, 2)
# self.tokens is ['du/dx0', 'd^2u/dx0^2']
# Here, derivs order is {'du/dx0': [0], 'd^2u/dx0^2': [0, 0]}
# self.tokens is ['u']
# Here, derivs order is {'u': [None]}
# The cardinality of defined token pool is [1 2 2 1]
# Among them, the pool contains [1 2 1]
# Creating new equation, sparsity value [0.00145792]
# New solution accepted, confirmed 1/10 solutions.
# Creating new equation, sparsity value [0.0001406]
# New solution accepted, confirmed 2/10 solutions.
# Creating new equation, sparsity value [0.00340552]
# New solution accepted, confirmed 3/10 solutions.
# Creating new equation, sparsity value [8.30535595e-06]
# New solution accepted, confirmed 4/10 solutions.
# Creating new equation, sparsity value [1.06591747e-06]
# New solution accepted, confirmed 5/10 solutions.
# Creating new equation, sparsity value [1.61298252e-06]
# New solution accepted, confirmed 6/10 solutions.
# Creating new equation, sparsity value [3.57029357e-06]
# New solution accepted, confirmed 7/10 solutions.
# Creating new equation, sparsity value [0.0001325]
# New solution accepted, confirmed 8/10 solutions.
# Creating new equation, sparsity value [0.00017616]
# New solution accepted, confirmed 9/10 solutions.
# Creating new equation, sparsity value [2.31198417e-05]
# Creating new equation, sparsity value [3.29273487e-05]
# New solution accepted, confirmed 10/10 solutions.
# best_obj 2
# The optimization has been conducted.
#
#
# 0-th non-dominated level
#
#
# 1.4986580913582268 * t{power: 1.0, dim: 0.0} + 0.0 * u{power: 1.0} * cos{power: 1.0, freq: 2.0000000546991195, dim: 0.0} + -1.0037791742287405 * du/dx0{power: 1.0} * sin{power: 1.0, freq: 1.9999998732536615, dim: 0.0} + 0.0 * t{power: 1.0, dim: 0.0} * cos{power: 1.0, freq: 1.9999998753027146, dim: 0.0} + -3.971082698119918 * u{power: 1.0} + -0.03412274168801577 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0023853929395590955}} , with objective function values of [1.49446993 4.5       ]
#
# -0.9634535510003018 * u{power: 1.0} * sin{power: 1.0, freq: 2.0000004296342664, dim: 0.0} + 0.3740077136693194 * t{power: 1.0, dim: 0.0} * cos{power: 1.0, freq: 2.0000003265552526, dim: 0.0} + -0.11656032966729578 * t{power: 1.0, dim: 0.0} + 0.0 * u{power: 1.0} + 0.0 * d^2u/dx0^2{power: 1.0} + 1.223134033566483 = du/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0053615462645096555}} , with objective function values of [2.87547763 3.5       ]
#
# 0.0 * u{power: 1.0} * cos{power: 1.0, freq: 2.0000003116936758, dim: 0.0} + -3.971083436192441 * u{power: 1.0} + -1.0037790315907045 * du/dx0{power: 1.0} * sin{power: 1.0, freq: 1.9999995335936425, dim: 0.0} + 1.498657824599564 * t{power: 1.0, dim: 0.0} + 0.0 * u{power: 1.0} * t{power: 1.0, dim: 0.0} + -0.03412167845838214 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0028433576447225188}} , with objective function values of [1.49446812 4.5       ]
#
# -0.11656064936673075 * t{power: 1.0, dim: 0.0} + 0.0 * d^2u/dx0^2{power: 1.0} + -0.9634551423437475 * u{power: 1.0} * sin{power: 1.0, freq: 1.9999997209458562, dim: 0.0} + 0.0 * d^2u/dx0^2{power: 1.0} * u{power: 1.0} + 0.37400626852397906 * t{power: 1.0, dim: 0.0} * cos{power: 1.0, freq: 1.9999998753027146, dim: 0.0} + 1.223134721924885 = du/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0046428619550476615}} , with objective function values of [2.87548367 3.5       ]
#
# -0.03028120742240644 * t{power: 1.0, dim: 0.0} + 2.023641341819518 * u{power: 1.0} * cos{power: 1.0, freq: 2.000000379922851, dim: 0.0} + -0.7850103447743252 * t{power: 1.0, dim: 0.0} * cos{power: 1.0, freq: 1.9999999071429797, dim: 0.0} + -0.21162275284825374 * u{power: 1.0} + -0.20842768517542543 * du/dx0{power: 1.0} + -1.1856705730541401 = du/dx0{power: 1.0} * sin{power: 1.0, freq: 1.9999999665861108, dim: 0.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.005970151788146267}} , with objective function values of [0.58916625 5.5       ]

# %%
epde_search_obj.visualize_solutions()
# Out:
# $\begin{eqnarray*} \frac{\partial ^2u}{\partial x_0^2} = 1.499t + -1.004\frac{\partial u}{\partial x_0} \cdot sin^{1.0}(2.0 x_{0.0}) + -3.971u + -3.412\cdot 10^{-2}  \end{eqnarray*}$
# $\begin{eqnarray*} \frac{\partial u}{\partial x_0} = -9.635\cdot 10^{-1} u \cdot sin^{1.0}(2.0 x_{0.0}) + 3.74\cdot 10^{-1} t \cdot cos^{1.0}(2.0 x_{0.0}) + -1.166\cdot 10^{-1} t + 1.223 \end{eqnarray*}$
# $\begin{eqnarray*} \frac{\partial u}{\partial x_0} \cdot sin^{1.0}(2.0 x_{0.0}) = -3.028\cdot 10^{-2} t + 2.024u \cdot cos^{1.0}(2.0 x_{0.0}) + -7.85\cdot 10^{-1} t \cdot cos^{1.0}(2.0 x_{0.0}) + -2.116\cdot 10^{-1} u + -2.084\cdot 10^{-1} \frac{\partial u}{\partial x_0} + -1.186 \end{eqnarray*}$

# %%
sys = epde_search_obj.get_equations_by_complexity(4.5)[0]

# %%
sys.text_form
# Out:
# "1.4986580913582268 * t{power: 1.0, dim: 0.0} + 0.0 * u{power: 1.0} * cos{power: 1.0, freq: 2.0000000546991195, dim: 0.0} + -1.0037791742287405 * du/dx0{power: 1.0} * sin{power: 1.0, freq: 1.9999998732536615, dim: 0.0} + 0.0 * t{power: 1.0, dim: 0.0} * cos{power: 1.0, freq: 1.9999998753027146, dim: 0.0} + -3.971082698119918 * u{power: 1.0} + -0.03412274168801577 = d^2u/dx0^2{power: 1.0}\n{'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0023853929395590955}}"

# %% [markdown]
# While there are multiple equations on the Pareto frontier, we can establish two candidates for the knee-points (for brevity they are denoted by their complexities: 4 and 4.5). The further increase in complexity does not provide significant error decrease, thus is not necessary. We shall analyze the process representation quality on the test dataset by solving initial value problem.
#
# The equation with complexity of 4.5 is second-order, thus to solve it we need the function value and the solution derivatve

# %%
import torch
from epde.interface.solver_integration import BoundaryConditions, BOPElement

eq_1 = epde_search_obj.get_equations_by_complexity(4.5)[0]
print(eq_1.text_form)
# Out:
# 1.4986580913582268 * t{power: 1.0, dim: 0.0} + 0.0 * u{power: 1.0} * cos{power: 1.0, freq: 2.0000000546991195, dim: 0.0} + -1.0037791742287405 * du/dx0{power: 1.0} * sin{power: 1.0, freq: 1.9999998732536615, dim: 0.0} + 0.0 * t{power: 1.0, dim: 0.0} * cos{power: 1.0, freq: 1.9999998753027146, dim: 0.0} + -3.971082698119918 * u{power: 1.0} + -0.03412274168801577 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0023853929395590955}}

# %%
def get_ode_bop(key, var, term, grid_loc, value):
    bop = BOPElement(axis = 0, key = key, term = term, power = 1, var = var)
    bop_grd_np = np.array([[grid_loc,]])
    bop.set_grid(torch.from_numpy(bop_grd_np).type(torch.FloatTensor))
    bop.values = torch.from_numpy(np.array([[value,]])).float()
    return bop

bop_u = get_ode_bop('u', 0, [None], t_test[0], x_test[0])

# Set derivative with central finite difference
bop_du = get_ode_bop('dudt', 0, [0,], t_test[0], (x_test[1] - x_train[-1])/(2*(t_test[1] - t_test[0])))

# %%
t_test.shape
t_test_oversampled = np.linspace(t_test[0], t_test[-1], 160)

# %%
from epde.interface.solver_integration import SystemSolverInterface
interface = SystemSolverInterface(eq_1)
interface.form(grids = [t_test,])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _term_solver_form(term, grids, default_domain, variables)
#     334                 try:
# --> 335                     cur_deriv_var = variables.index(factor.ftype)
#     336                 except ValueError:
#
# ValueError: 'poly of u' is not in list
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-30-a1cd4d98198b> in <module>
#       1 from epde.interface.solver_integration import SystemSolverInterface
#       2 interface = SystemSolverInterface(eq_1)
# ----> 3 interface.form(grids = [t_test,])
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in form(self, grids)
#     420         for equation in self.adaptee.vals:
#     421             equation_forms.append((equation.main_var_to_explain,
# --> 422                                    self._equation_solver_form(equation, variables=self.variables,
#     423                                                               grids=grids)))
#     424         return equation_forms
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _equation_solver_form(self, equation, variables, grids)
#     383                     weight = equation.weights_final[term_idx-1]
#     384                 if not np.isclose(weight, 0, rtol = self.coeff_tol):
# --> 385                     _solver_form[term.name] = self._term_solver_form(term, grids, default_domain, variables)
#     386                     _solver_form[term.name]['coeff'] = _solver_form[term.name]['coeff'] * weight
#     387                     _solver_form[term.name]['coeff'] = torch.flatten(_solver_form[term.name]['coeff']).unsqueeze(1).type(torch.FloatTensor)
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _term_solver_form(term, grids, default_domain, variables)
#     336                 except ValueError:
#     337                     raise ValueError(
# --> 338                         f'Variable family of passed derivative {variables}, other than {cur_deriv_var}')
#     339                 derivs_detected = True
#     340
#
# UnboundLocalError: local variable 'cur_deriv_var' referenced before assignment

# %%
eq_1.solver_form
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-1f3e61c7ae8a> in <module>
# ----> 1 eq_1.solver_form
#
# AttributeError: 'SoEq' object has no attribute 'solver_form'

# %%
pred_u = epde_search_obj.predict(system=eq_1, boundary_conditions = [bop_u(), bop_du()], # })
                                 grid = [t_test,], mode='autograd', solver_kwargs = {'derivative_points': 3,
                                                                               'step_plot_save':True, 'use_cache' : False,
                                                                               'optimizer_mode': 'LBFGS', 
                                                                               'learning_rate': 1e-3, 'tmax' : 2*1e5})
# Out:
# Using explicitly sent system of equations.
# dimensionality is 1
# grid.shape is (160,)
# Shape of the grid for solver torch.Size([160, 1])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _term_solver_form(term, grids, default_domain, variables)
#     334                 try:
# --> 335                     cur_deriv_var = variables.index(factor.ftype)
#     336                 except ValueError:
#
# ValueError: 'poly of u' is not in list
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-32-00b922619724> in <module>
# ----> 1 pred_u = epde_search_obj.predict(system=eq_1, boundary_conditions = [bop_u(), bop_du()], # })
#       2                                  grid = [t_test,], mode='autograd', solver_kwargs = {'derivative_points': 3,
#       3                                                                                'step_plot_save':True, 'use_cache' : False,
#       4                                                                                'optimizer_mode': 'LBFGS',
#       5                                                                                'learning_rate': 1e-3, 'tmax' : 2*1e5})
#
# ~/epde/EPDE_main/epde/interface/interface.py in predict(self, system, boundary_conditions, grid, data, system_file, solver_kwargs, mode)
#     827         print(f'grid.shape is {grid[0].shape}')
#     828         print(f'Shape of the grid for solver {adapter.convert_grid(grid, mode = mode).shape}')
# --> 829         solution_model = adapter.solve_epde_system(system = system, grids = grid, data = data,
#     830                                                    boundary_conditions = boundary_conditions, mode = mode)
#     831         if mode == 'mat':
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in solve_epde_system(self, system, grids, boundary_conditions, mode, data)
#     479         system_interface = SystemSolverInterface(system_to_adapt=system)
#     480
# --> 481         system_solver_forms = system_interface.form(grids)
#     482         if boundary_conditions is None:
#     483             op_gen = PregenBOperator(system=system,
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in form(self, grids)
#     420         for equation in self.adaptee.vals:
#     421             equation_forms.append((equation.main_var_to_explain,
# --> 422                                    self._equation_solver_form(equation, variables=self.variables,
#     423                                                               grids=grids)))
#     424         return equation_forms
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _equation_solver_form(self, equation, variables, grids)
#     383                     weight = equation.weights_final[term_idx-1]
#     384                 if not np.isclose(weight, 0, rtol = self.coeff_tol):
# --> 385                     _solver_form[term.name] = self._term_solver_form(term, grids, default_domain, variables)
#     386                     _solver_form[term.name]['coeff'] = _solver_form[term.name]['coeff'] * weight
#     387                     _solver_form[term.name]['coeff'] = torch.flatten(_solver_form[term.name]['coeff']).unsqueeze(1).type(torch.FloatTensor)
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _term_solver_form(term, grids, default_domain, variables)
#     336                 except ValueError:
#     337                     raise ValueError(
# --> 338                         f'Variable family of passed derivative {variables}, other than {cur_deriv_var}')
#     339                 derivs_detected = True
#     340
#
# UnboundLocalError: local variable 'cur_deriv_var' referenced before assignment

# %%
pred_u = epde_search_obj.predict(system=eq_1, boundary_conditions = [bop_u(), bop_du()], # })
                                 grid = [t_test,], mode='NN')#, solver_kwargs = {'derivative_points': 3,
                                                                   #            'step_plot_save':True, 'use_cache' : False,
                                                                   #            'optimizer_mode': 'LBFGS', 
                                                                   #            'learning_rate': 1e-3, 'tmax' : 2*1e5})
# Out:
# Using explicitly sent system of equations.
# dimensionality is 1
# grid.shape is (160,)
# Shape of the grid for solver torch.Size([160, 1])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _term_solver_form(term, grids, default_domain, variables)
#     334                 try:
# --> 335                     cur_deriv_var = variables.index(factor.ftype)
#     336                 except ValueError:
#
# ValueError: 'poly of u' is not in list
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-33-dbde2eb7f0a5> in <module>
# ----> 1 pred_u = epde_search_obj.predict(system=eq_1, boundary_conditions = [bop_u(), bop_du()], # })
#       2                                  grid = [t_test,], mode='NN')#, solver_kwargs = {'derivative_points': 3,
#       3                                                                    #            'step_plot_save':True, 'use_cache' : False,
#       4                                                                    #            'optimizer_mode': 'LBFGS',
#       5                                                                    #            'learning_rate': 1e-3, 'tmax' : 2*1e5})
#
# ~/epde/EPDE_main/epde/interface/interface.py in predict(self, system, boundary_conditions, grid, data, system_file, solver_kwargs, mode)
#     827         print(f'grid.shape is {grid[0].shape}')
#     828         print(f'Shape of the grid for solver {adapter.convert_grid(grid, mode = mode).shape}')
# --> 829         solution_model = adapter.solve_epde_system(system = system, grids = grid, data = data,
#     830                                                    boundary_conditions = boundary_conditions, mode = mode)
#     831         if mode == 'mat':
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in solve_epde_system(self, system, grids, boundary_conditions, mode, data)
#     479         system_interface = SystemSolverInterface(system_to_adapt=system)
#     480
# --> 481         system_solver_forms = system_interface.form(grids)
#     482         if boundary_conditions is None:
#     483             op_gen = PregenBOperator(system=system,
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in form(self, grids)
#     420         for equation in self.adaptee.vals:
#     421             equation_forms.append((equation.main_var_to_explain,
# --> 422                                    self._equation_solver_form(equation, variables=self.variables,
#     423                                                               grids=grids)))
#     424         return equation_forms
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _equation_solver_form(self, equation, variables, grids)
#     383                     weight = equation.weights_final[term_idx-1]
#     384                 if not np.isclose(weight, 0, rtol = self.coeff_tol):
# --> 385                     _solver_form[term.name] = self._term_solver_form(term, grids, default_domain, variables)
#     386                     _solver_form[term.name]['coeff'] = _solver_form[term.name]['coeff'] * weight
#     387                     _solver_form[term.name]['coeff'] = torch.flatten(_solver_form[term.name]['coeff']).unsqueeze(1).type(torch.FloatTensor)
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in _term_solver_form(term, grids, default_domain, variables)
#     336                 except ValueError:
#     337                     raise ValueError(
# --> 338                         f'Variable family of passed derivative {variables}, other than {cur_deriv_var}')
#     339                 derivs_detected = True
#     340
#
# UnboundLocalError: local variable 'cur_deriv_var' referenced before assignment

# %%
pred_u = pred_u.reshape(-1)

# %% [markdown]
# To evaluate the quality of obtained equation, we will check the MAPE error and visualize the solution oftest domain.

# %%
if isinstance(pred_u, torch.Tensor):
    pred_u = pred_u.detach().numpy()

# %%
print(f'MAPE on the test dataset is {np.mean(np.abs((pred_u - x_test)/x_test))}')

plt.plot(t_test, pred_u, color = 'b', label = 'Automatic solution of the equation')
plt.plot(t_test[::3], x_test[::3], '*', color = 'r', label = 'Referential data')
plt.xlabel('Time'); plt.ylabel('Predicted value') 
plt.grid()
plt.legend()
plt.show()
# Out:
# MAPE on the test dataset is 0.7207565967327436

# %%
print(f'MAPE on the test dataset is {np.mean(np.abs((pred_u - x_test)/x_test))}')

plt.plot(t_test, pred_u, color = 'b', label = 'Automatic solution of the equation')
plt.plot(t_test[::3], x_test[::3], '*', color = 'r', label = 'Referential data')
plt.xlabel('Time'); plt.ylabel('Predicted value') 
plt.grid()
plt.legend()
plt.show()
# Out:
# MAPE on the test dataset is 0.778165922990358

# %%
eq2 = epde_search_obj.get_equations_by_complexity(4)[0]
eq2.text_form
# Out:
# "0.18838065425022715 * du/dx0{power: 1.0} + 0.0 * du/dx0{power: 1.0} * cos{power: 1.0, freq: 2.000000455717803, dim: 0.0} + -4.1641631373187735 * u{power: 1.0} + 1.6536874729492648 * t{power: 1.0, dim: 0.0} + 0.0 * t{power: 1.0, dim: 0.0} * du/dx0{power: 1.0} + 0.46261263867880514 = d^2u/dx0^2{power: 1.0}\n{'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.65, 0.35]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0036480405054872557}}"

# %% [markdown]
# This equation has the first order, thus only a single initial condition $u|_{t = t_{val, 0}}$ is needed, and we get it from the data.

# %%
bop_u = get_ode_bop('u', 0, [None], t_test[0], x_test[0])
pred_u = epde_search_obj.predict(system=eq2, 
                                 boundary_conditions = [bop_u(),],# bop_du()],
                                 grid = [t_test,], strategy='autograd')
pred_u = pred_u.reshape(-1)
# Out:
# Using explicitly sent system of equations.
# dimensionality is 1
# grid.shape is (160,)
# Shape of the grid for solver torch.Size([160, 1])
# Grid is  <class 'torch.Tensor'> torch.Size([160, 1])
# torch.Size([1])
# [2023-11-14 13:51:32.210840] initial (min) loss is 110.7210922241211
# [2023-11-14 13:51:32.260130] Print every 1000 step
# Step = 0 loss = 110.721092 normalized loss line= -0.000000x+1.000000. There was 1 stop dings already.
# [2023-11-14 13:51:37.926107] No improvement in 100 steps
# Step = 162 loss = 0.660284 normalized loss line= -1.009283x+69.538913. There was 1 stop dings already.
# [2023-11-14 13:51:45.445565] No improvement in 100 steps
# Step = 368 loss = 0.650706 normalized loss line= -0.000093x+1.004540. There was 2 stop dings already.
# [2023-11-14 13:52:06.541110] Print every 1000 step
# Step = 1000 loss = 0.383480 normalized loss line= -0.001463x+1.400814. There was 3 stop dings already.
# [2023-11-14 13:52:37.372257] Print every 1000 step
# Step = 2000 loss = 0.288431 normalized loss line= 0.006223x+1.116119. There was 3 stop dings already.
# [2023-11-14 13:53:06.758361] Print every 1000 step
# Step = 3000 loss = 0.193387 normalized loss line= -0.000468x+1.094312. There was 3 stop dings already.
# [2023-11-14 13:53:36.168219] Print every 1000 step
# Step = 4000 loss = 0.120251 normalized loss line= -0.024366x+2.653204. There was 3 stop dings already.
# [2023-11-14 13:54:05.435777] Print every 1000 step
# Step = 5000 loss = 0.039498 normalized loss line= -0.001617x+1.228692. There was 3 stop dings already.
# [2023-11-14 13:54:35.300291] No improvement in 100 steps
# Step = 5977 loss = 0.021884 normalized loss line= -0.001817x+0.942232. There was 3 stop dings already.
# [2023-11-14 13:54:36.265653] Print every 1000 step
# Step = 6000 loss = 0.035748 normalized loss line= -0.001112x+0.576807. There was 4 stop dings already.
# [2023-11-14 13:55:06.753887] Print every 1000 step
# Step = 7000 loss = 0.069820 normalized loss line= -0.004764x+1.056012. There was 4 stop dings already.
# [2023-11-14 13:55:12.579333] No improvement in 100 steps
# Step = 7180 loss = 0.020659 normalized loss line= -0.003502x+0.699808. There was 4 stop dings already.
# [2023-11-14 13:55:18.234232] No improvement in 100 steps
# Step = 7356 loss = 0.010884 normalized loss line= -0.060570x+5.328152. There was 5 stop dings already.
# [2023-11-14 13:55:21.421261] No improvement in 100 steps
# Step = 7456 loss = 0.004902 normalized loss line= -0.186821x+18.067813. There was 6 stop dings already.
# [2023-11-14 13:55:31.717361] No improvement in 100 steps
# Step = 7797 loss = 0.002511 normalized loss line= -0.501087x+37.221588. There was 7 stop dings already.
# [2023-11-14 13:55:37.923225] Print every 1000 step
# Step = 8000 loss = 0.013245 normalized loss line= 0.001771x+0.206049. There was 8 stop dings already.
# [2023-11-14 13:55:41.606746] No improvement in 100 steps
# Step = 8115 loss = 0.005053 normalized loss line= 0.022909x+4.996221. There was 8 stop dings already.
# [2023-11-14 13:55:47.369590] No improvement in 100 steps
# Step = 8304 loss = 0.002487 normalized loss line= -0.029745x+16.605951. There was 9 stop dings already.
# [2023-11-14 13:55:50.557710] No improvement in 100 steps
# Step = 8404 loss = 0.030757 normalized loss line= -0.005574x+1.051347. There was 10 stop dings already.
# [2023-11-14 13:55:53.725648] No improvement in 100 steps
# Step = 8504 loss = 0.022839 normalized loss line= -0.054017x+4.271043. There was 11 stop dings already.

# %%
print(f'MAPE on the test dataset is {np.mean(np.abs((pred_u - x_test)/x_test))}')

plt.plot(t_test, pred_u, color = 'b', label = 'Automatic solution of the equation')
plt.plot(t_test[::3], x_test[::3], '*', color = 'r', label = 'Referential data')
plt.grid()
plt.legend()
plt.show()
# Out:
# MAPE on the test dataset is 1.7942529267020053

# %% [markdown]
# In the result we can see, that the equation like $1.42 t - 3.81 u -0.96 u'' + 0.007 = u' \sin{(2.0 t)}$ can decently describe the process, while the alternative equation is not representative enough.

# %% [markdown]
# ## Van der Pol oscillator

# %% [markdown]
# The problem of non-linear ordinary differential equations discovery can be demonstrated with the Van der Pol oscillator. Initially introduced to describe the relaxation-oscillation cycle produced by the electromagnetic field, the model has found applications in other spheres of science, such as biology or seismology. Its state is governed by equation $u'' + \mathcal{E}(u^2 - 1)u' + u = 0$, where $\mathcal{E}$ is a positive constant (in the example we will use $\mathcal{E} = 0.2$). To prepare synthetic dataset we will again use Runge-Kutta method:

# %%
def VdP_by_RK(initial: tuple, timestep: float, steps: int, epsilon: float):
    res = np.full(shape = (steps, 2), fill_value = initial, dtype=np.float64)
    for step in range(steps-1):
        t = step*timestep
        k1 = res[step, 1] ; x1 = res[step, 0] + timestep/2. * k1
        l1 =  - epsilon*(res[step, 0]**2 - 1)*res[step, 1] - res[step, 0]; y1 = res[step, 1] + timestep/2. * l1

        k2 = y1; x2 = res[step, 0] + timestep/2. * k2
        l2 = - epsilon*(x1**2 - 1)*y1 - x1; y2 = res[step, 1] + timestep/2. * l2

        k3 = y2
        l3 = - epsilon*(x2**2 - 1)*y2 - x2
        
        x3 = res[step, 0] + timestep * k1 - 2 * timestep * k2 + 2 * timestep * k3
        y3 = res[step, 1] + timestep * l1 - 2 * timestep * l2 + 2 * timestep * l3
        k4 = y3
        l4 = - epsilon*(x3**2 - 1)*y3 - x3
        
        res[step+1, 0] = res[step, 0] + timestep / 6. * (k1 + 2 * k2 + 2 * k3 + k4)
        res[step+1, 1] = res[step, 1] + timestep / 6. * (l1 + 2 * l2 + 2 * l3 + l4)
    return res

def prepare_VdP_data(initial = (np.sqrt(3)/2., 1./2.), step = 0.05, steps_num = 640, epsilon = 0.2):
    t = np.arange(start = 0., stop = step * steps_num, step = step)
    solution = VdP_by_RK(initial=initial, timestep=step, steps=steps_num, 
                                      epsilon=epsilon)
    return t, solution

# %%
def epde_discovery_as_ode(t, x, use_ann:bool = False):
    dimensionality = x.ndim - 1
    epde_search_obj = epde.EpdeSearch(use_solver = False, dimensionality = dimensionality, boundary = 50,
                                           coordinate_tensors = [t,], verbose_params = {'show_iter_idx' : False})
    if use_ann:
        epde_search_obj.set_preprocessor(default_preprocessor_type='ANN',
                                         preprocessor_kwargs={'epochs_max' : 35000})
    else:
        epde_search_obj.set_preprocessor(default_preprocessor_type='poly',
                                         preprocessor_kwargs={'use_smoothing' : True, 'sigma' : 1, 
                                                              'polynomial_window' : 15, 'poly_order' : 12})
    popsize = 12
    epde_search_obj.set_moeadd_params(population_size = popsize, training_epochs=125)
    
    factors_max_number = {'factors_num' : [1, 2, 3], 'probas' : [0.4, 0.3, 0.3]}
    
    epde_search_obj.fit(data=[x,], variable_names=['u',], max_deriv_order=(3,),
                        equation_terms_max_number=6, data_fun_pow = 2,
                        equation_factors_max_number=factors_max_number,
                        eq_sparsity_interval=(1e-13, 1e0))
    
    epde_search_obj.equations(only_print = True, num = 1)
    
    return epde_search_obj

# %%
t, x_stacked = prepare_VdP_data()
t_max = 320
x, y = x_stacked[:, 0], x_stacked[:, 1]
t_train, t_test = t[:t_max], t[:t_max]
x_train, x_test = x[:t_max], x[t_max:]
y_train, y_test = y[:t_max], y[t_max:]
plt.plot(x_train, y_train, color = 'midnightblue')
plt.plot(x_test[::3], y_test[::3], color = 'orangered')
plt.show()

# %%
epde_search_obj = epde_discovery_as_ode(t_train, x_train, False)
# Out:
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7fa2e7f9dfa0>
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7fa2e7f9dfa0>
# Deriv orders after definition [[None], [0], [0, 0], [0, 0, 0]]
# 320
# initial_shape (320,) derivs_tensor.shape (320, 3)
# self.tokens is ['u', 'du/dx0', 'd^2u/dx0^2', 'd^3u/dx0^3']
# Here, derivs order is {'u': [None], 'du/dx0': [0], 'd^2u/dx0^2': [0, 0], 'd^3u/dx0^3': [0, 0, 0]}
# The cardinality of defined token pool is [4]
# Among them, the pool contains [4]
# Creating new equation, sparsity value [0.68407237]
# New solution accepted, confirmed 1/12 solutions.
# Creating new equation, sparsity value [5.07778797e-08]
# New solution accepted, confirmed 2/12 solutions.
# Creating new equation, sparsity value [2.64026735e-06]
# New solution accepted, confirmed 3/12 solutions.
# Creating new equation, sparsity value [2.57395265e-11]
# New solution accepted, confirmed 4/12 solutions.
# Creating new equation, sparsity value [6.03921139e-06]
# New solution accepted, confirmed 5/12 solutions.
# Creating new equation, sparsity value [1.17686412e-12]
# New solution accepted, confirmed 6/12 solutions.
# Creating new equation, sparsity value [0.07571987]
# New solution accepted, confirmed 7/12 solutions.
# Creating new equation, sparsity value [8.13947394e-05]
# New solution accepted, confirmed 8/12 solutions.
# Creating new equation, sparsity value [1.13621263e-10]
# New solution accepted, confirmed 9/12 solutions.
# Creating new equation, sparsity value [5.95754591e-05]
# New solution accepted, confirmed 10/12 solutions.
# Creating new equation, sparsity value [1.69718792e-06]
# New solution accepted, confirmed 11/12 solutions.
# Creating new equation, sparsity value [0.00455109]
# New solution accepted, confirmed 12/12 solutions.
# [0.56, 0.43999999999999995] [[0.28, 0.72], [0.18, 0.8200000000000001], [0.04, 0.96], [0.56, 0.43999999999999995], [0.78, 0.21999999999999997]]
# [0.18, 0.8200000000000001] [[0.28, 0.72], [0.18, 0.8200000000000001], [0.04, 0.96], [0.56, 0.43999999999999995], [0.78, 0.21999999999999997], [0.26, 0.74], [0.54, 0.45999999999999996], [0.0, 1.0], [0.76, 0.24], [0.66, 0.33999999999999997], [0.36, 0.64]]
# [0.28, 0.72] [[0.28, 0.72], [0.18, 0.8200000000000001], [0.04, 0.96], [0.56, 0.43999999999999995], [0.78, 0.21999999999999997], [0.26, 0.74], [0.54, 0.45999999999999996], [0.0, 1.0], [0.76, 0.24], [0.66, 0.33999999999999997], [0.36, 0.64]]
# [0.78, 0.21999999999999997] [[0.28, 0.72], [0.18, 0.8200000000000001], [0.04, 0.96], [0.56, 0.43999999999999995], [0.78, 0.21999999999999997], [0.26, 0.74], [0.54, 0.45999999999999996], [0.0, 1.0], [0.76, 0.24], [0.66, 0.33999999999999997], [0.36, 0.64]]
# best_obj 2
# The optimization has been conducted.
#
#
# 0-th non-dominated level
#
#
# -1.0004250731895417 * u{power: 1.0} + 0.0 * u{power: 2.0} + -0.199071572278306 * u{power: 2.0} * du/dx0{power: 1.0} + 0.199136389092804 * du/dx0{power: 1.0} + 0.0 * d^2u/dx0^2{power: 1.0} * u{power: 1.0} + -1.2637814583985259e-05 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.003602331114930889}} , with objective function values of [2.91261232e-03 5.00000000e+00]
#
# 0.0 * d^3u/dx0^3{power: 1.0} + -1.0134740998571992 * u{power: 2.0} + 0.0 * d^3u/dx0^3{power: 2.0} * u{power: 1.0} + 0.0 * d^2u/dx0^2{power: 2.0} + 0.0 * du/dx0{power: 2.0} * u{power: 1.0} + 0.007105582081027101 = d^2u/dx0^2{power: 1.0} * u{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.22922398791970441}} , with objective function values of [1.62371108 3.5       ]
#
# -1.0074402446941904 * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * d^3u/dx0^3{power: 2.0} + 0.0 * d^3u/dx0^3{power: 1.0} + 0.0 * d^2u/dx0^2{power: 2.0} + 0.0 * d^2u/dx0^2{power: 1.0} * u{power: 1.0} + 0.010341093015417396 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.05091368328398132}} , with objective function values of [2.02312901 2.5       ]
#
# 0.0 * d^2u/dx0^2{power: 1.0} * du/dx0{power: 2.0} + 0.0 * d^2u/dx0^2{power: 2.0} * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * d^3u/dx0^3{power: 1.0} + 0.0 * du/dx0{power: 1.0} * u{power: 1.0} * d^2u/dx0^2{power: 1.0} + -1.0074402446941904 * u{power: 1.0} + 0.010341093015417396 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.09129903995975693}} , with objective function values of [2.02312901 2.5       ]
#
# 0.0 * du/dx0{power: 2.0} + -1.0134740998571992 * u{power: 2.0} + 0.0 * d^3u/dx0^3{power: 1.0} * du/dx0{power: 2.0} + 0.0 * d^2u/dx0^2{power: 2.0} * d^3u/dx0^3{power: 1.0} + 0.0 * u{power: 1.0} + 0.007105582081027101 = d^2u/dx0^2{power: 1.0} * u{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.07042421797663274}} , with objective function values of [1.62371108 3.5       ]
#
# 0.0 * d^3u/dx0^3{power: 1.0} + -1.0074402446941904 * u{power: 1.0} + 0.0 * u{power: 2.0} * du/dx0{power: 1.0} + 0.0 * u{power: 1.0} * du/dx0{power: 1.0} + 0.0 * d^2u/dx0^2{power: 2.0} * du/dx0{power: 1.0} + 0.010341093015417396 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.05274143975152764}} , with objective function values of [2.02312901 2.5       ]
#
# -1.0074402446941904 * u{power: 1.0} + 0.0 * d^3u/dx0^3{power: 1.0} * d^2u/dx0^2{power: 1.0} * u{power: 1.0} + 0.0 * du/dx0{power: 2.0} * d^3u/dx0^3{power: 1.0} + 0.0 * d^2u/dx0^2{power: 1.0} * d^3u/dx0^3{power: 1.0} + 0.0 * du/dx0{power: 1.0} * d^3u/dx0^3{power: 1.0} + 0.010341093015417396 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0693341202635791}} , with objective function values of [2.02312901 2.5       ]
#
# 0.0 * d^3u/dx0^3{power: 1.0} + 0.0 * d^2u/dx0^2{power: 2.0} * u{power: 1.0} + 0.0 * d^3u/dx0^3{power: 1.0} * du/dx0{power: 1.0} + -1.0074402446941904 * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * u{power: 1.0} * d^3u/dx0^3{power: 1.0} + 0.010341093015417396 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.06766473626488134}} , with objective function values of [2.02312901 2.5       ]
#
# 0.0 * u{power: 1.0} + 0.0 * du/dx0{power: 2.0} * d^3u/dx0^3{power: 1.0} + -1.0134740998571992 * u{power: 2.0} + 0.0 * d^3u/dx0^3{power: 1.0} * u{power: 1.0} * d^2u/dx0^2{power: 1.0} + 0.0 * d^2u/dx0^2{power: 2.0} + 0.007105582081027101 = d^2u/dx0^2{power: 1.0} * u{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.048546697715977485}} , with objective function values of [1.62371108 3.5       ]
#
# -1.0134740998571992 * u{power: 2.0} + 0.0 * d^3u/dx0^3{power: 2.0} + 0.0 * u{power: 1.0} + 0.0 * d^3u/dx0^3{power: 1.0} + 0.0 * d^2u/dx0^2{power: 1.0} * d^3u/dx0^3{power: 1.0} * du/dx0{power: 1.0} + 0.007105582081027101 = u{power: 1.0} * d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.058443368838481245}} , with objective function values of [1.62371108 3.5       ]
#
# -1.0134740998571992 * u{power: 2.0} + 0.0 * du/dx0{power: 1.0} + 0.0 * d^2u/dx0^2{power: 1.0} + 0.0 * d^3u/dx0^3{power: 1.0} * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * d^3u/dx0^3{power: 1.0} + 0.007105582081027101 = d^2u/dx0^2{power: 1.0} * u{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.06001916632453692}} , with objective function values of [1.62371108 3.5       ]
#
# 0.0 * d^3u/dx0^3{power: 2.0} * d^2u/dx0^2{power: 1.0} + -1.0074402446941904 * u{power: 1.0} + 0.0 * d^3u/dx0^3{power: 1.0} + 0.0 * d^3u/dx0^3{power: 1.0} * du/dx0{power: 1.0} + 0.0 * u{power: 2.0} + 0.010341093015417396 = d^2u/dx0^2{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 6}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2, 3], 'probas': [0.4, 0.3, 0.3]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.07355703221940277}} , with objective function values of [2.02312901 2.5       ]

# %%
epde_search_obj.visualize_solutions()
# Out:
# $\begin{eqnarray*} \frac{\partial ^2u}{\partial x_0^2} = -1.0u + -1.991\cdot 10^{-1} \left(u\right)^{2.0} \cdot \frac{\partial u}{\partial x_0} + 1.991\cdot 10^{-1} \frac{\partial u}{\partial x_0} + -1.264\cdot 10^{-5}  \end{eqnarray*}$
# $\begin{eqnarray*} \frac{\partial ^2u}{\partial x_0^2} \cdot u = -1.013\left(u\right)^{2.0} + 7.106\cdot 10^{-3}  \end{eqnarray*}$
# $\begin{eqnarray*} \frac{\partial ^2u}{\partial x_0^2} = -1.007u + 1.034\cdot 10^{-2}  \end{eqnarray*}$

# %% [markdown]
# Let's extract equations, that can be useful for system description:
#
# *Note*: during other example launches, the discovered equations may be different. To proceed, adopt getting equations by complexities, according to the Pareto frontier.

# %%
eq_compl_5 = epde_search_obj.get_equations_by_complexity(5)[0]
eq_compl_3_5 = epde_search_obj.get_equations_by_complexity(3.5)[0]
eq_compl_2_5 = epde_search_obj.get_equations_by_complexity(2.5)[0]

# %% [markdown]
# The Pareto frontier is concave, having the relatively simple yet very descriptive equation, matching the equation $u'' = -u + 0.2 u' - 0.2 u^2 u' + \delta$, $\delta << 1$ which we will consider as a useful equation-based model of the process.
#
# Even though we already know, that it is very similar to the equation, from which we generated the data, we should still examine its predictive properties. Let's solve the equation with solver:

# %%
import torch
from epde.interface.solver_integration import BoundaryConditions, BOPElement

def get_ode_bop(key, var, term, grid_loc, value):
    bop = BOPElement(axis = 0, key = key, term = term, power = 1, var = var)
    bop_grd_np = np.array([[grid_loc,]])
    bop.set_grid(torch.from_numpy(bop_grd_np).type(torch.FloatTensor))
    bop.values = torch.from_numpy(np.array([[value,]])).float()
    return bop

# %%
bop_u = get_ode_bop('u', grid_loc = t_test[0], value = x_test[0], term = [None], var = 0)
bop_dudt = get_ode_bop('dudt', grid_loc = t_test[0], value = y_test[0], term = [0], var = 0)

#get solution for equation with complexity 5
pred_u_compl_5 = epde_search_obj.predict(system=eq_compl_5, boundary_conditions=[bop_u(), bop_dudt()], 
                                         grid = [t_test,], strategy='autograd')
pred_u_compl_5 = pred_u_compl_5.reshape(pred_u_compl_5.size)

#get solution for equation with complexity 3.5
pred_u_compl_3_5 = epde_search_obj.predict(system=eq_compl_3_5, boundary_conditions=[bop_u(), bop_dudt()], 
                                           grid = [t_test,], strategy='autograd')
pred_u_compl_3_5 = pred_u_compl_3_5.reshape(pred_u_compl_3_5.size)

#get solution for equation with complexity 7
pred_u_compl_2_5 = epde_search_obj.predict(system=eq_compl_2_5, boundary_conditions=[bop_u(), bop_dudt()], 
                                         grid = [t_test,], strategy='autograd')
pred_u_compl_2_5 = pred_u_compl_2_5.reshape(pred_u_compl_2_5.size)
# Out:
# Using explicitly sent system of equations.
# dimensionality is 1
# grid.shape is (320,)
# Shape of the grid for solver torch.Size([320, 1])
# Grid is  <class 'torch.Tensor'> torch.Size([320, 1])
# torch.Size([1])
# [2023-11-14 17:58:49.791355] initial (min) loss is 233.1897735595703
# [2023-11-14 17:58:49.937425] Print every 1000 step
# Step = 0 loss = 233.189774 normalized loss line= -0.000000x+1.000000. There was 1 stop dings already.
# [2023-11-14 18:00:24.333874] Print every 1000 step
# Step = 1000 loss = 0.000062 normalized loss line= -0.160467x+12.686782. There was 1 stop dings already.
# [2023-11-14 18:01:10.814415] No improvement in 100 steps
# Step = 1521 loss = 0.000237 normalized loss line= 0.049447x+-0.633838. There was 1 stop dings already.
# [2023-11-14 18:01:27.991496] No improvement in 100 steps
# Step = 1694 loss = 0.000027 normalized loss line= -0.316416x+22.806038. There was 2 stop dings already.
# [2023-11-14 18:01:51.412303] No improvement in 100 steps
# Step = 1922 loss = 0.000031 normalized loss line= 0.350093x+-5.413282. There was 3 stop dings already.
# [2023-11-14 18:01:58.999466] Print every 1000 step
# Step = 2000 loss = 0.000184 normalized loss line= 0.059932x+-0.926685. There was 4 stop dings already.
# [2023-11-14 18:02:10.903534] No improvement in 100 steps
# Step = 2141 loss = 0.097482 normalized loss line= 0.000252x+-0.006932. There was 4 stop dings already.
# [2023-11-14 18:02:29.050775] No improvement in 100 steps
# Step = 2358 loss = 0.003008 normalized loss line= 0.001394x+-0.034780. There was 5 stop dings already.
# [2023-11-14 18:02:37.355766] No improvement in 100 steps
# Step = 2458 loss = 0.000349 normalized loss line= -4.965745x+367.484717. There was 6 stop dings already.
# [2023-11-14 18:02:45.594016] No improvement in 100 steps
# Step = 2558 loss = 0.000413 normalized loss line= 0.013466x+0.024347. There was 7 stop dings already.
# [2023-11-14 18:02:58.904289] No improvement in 100 steps
# Step = 2722 loss = 0.002300 normalized loss line= 0.739356x+-21.050368. There was 8 stop dings already.
# [2023-11-14 18:03:07.370289] No improvement in 100 steps
# Step = 2822 loss = 0.000006 normalized loss line= -44.817778x+3184.812619. There was 9 stop dings already.
# [2023-11-14 18:03:21.852856] Print every 1000 step
# Step = 3000 loss = 0.000120 normalized loss line= -0.001993x+0.219720. There was 10 stop dings already.
# [2023-11-14 18:03:28.657963] No improvement in 100 steps
# Step = 3083 loss = 0.000075 normalized loss line= 0.001938x+-0.012034. There was 10 stop dings already.
# [2023-11-14 18:03:36.978000] No improvement in 100 steps
# Step = 3183 loss = 0.001598 normalized loss line= -0.361976x+39.470079. There was 11 stop dings already.
# Using explicitly sent system of equations.
# dimensionality is 1
# grid.shape is (320,)
# Shape of the grid for solver torch.Size([320, 1])
# Grid is  <class 'torch.Tensor'> torch.Size([320, 1])
# torch.Size([1])
# [2023-11-14 18:03:37.328033] initial (min) loss is 200.1282501220703
# [2023-11-14 18:03:37.400853] Print every 1000 step
# Step = 0 loss = 200.128250 normalized loss line= -0.000000x+1.000000. There was 1 stop dings already.
# [2023-11-14 18:04:41.636831] Print every 1000 step
# Step = 1000 loss = 0.000088 normalized loss line= -0.021077x+3.438938. There was 1 stop dings already.
# [2023-11-14 18:05:04.709505] No improvement in 100 steps
# Step = 1397 loss = 0.000453 normalized loss line= -0.000151x+0.125265. There was 1 stop dings already.
# [2023-11-14 18:05:39.323649] No improvement in 100 steps
# Step = 1938 loss = 0.000689 normalized loss line= 2.931009x+-53.993941. There was 2 stop dings already.
# [2023-11-14 18:05:42.996548] Print every 1000 step
# Step = 2000 loss = 0.000035 normalized loss line= 58.498368x+-1077.635031. There was 3 stop dings already.
# [2023-11-14 18:06:07.027530] No improvement in 100 steps
# Step = 2424 loss = 0.000422 normalized loss line= 2.293542x+11.476926. There was 3 stop dings already.
# [2023-11-14 18:06:38.052640] No improvement in 100 steps
# Step = 2906 loss = 0.000577 normalized loss line= -0.296516x+95.411703. There was 4 stop dings already.
# [2023-11-14 18:06:44.834770] Print every 1000 step
# Step = 3000 loss = 0.000012 normalized loss line= -13.907248x+4475.023333. There was 5 stop dings already.
# [2023-11-14 18:07:09.906042] No improvement in 100 steps
# Step = 3399 loss = 0.000616 normalized loss line= -0.000016x+0.014874. There was 5 stop dings already.
# [2023-11-14 18:07:41.630787] No improvement in 100 steps
# Step = 3890 loss = 0.000411 normalized loss line= -0.000019x+0.008961. There was 6 stop dings already.
# [2023-11-14 18:07:49.197817] Print every 1000 step
# Step = 4000 loss = 0.000003 normalized loss line= -299.401416x+27736.844116. There was 7 stop dings already.
# [2023-11-14 18:08:15.333696] No improvement in 100 steps
# Step = 4385 loss = 0.000295 normalized loss line= -0.000005x+0.006346. There was 7 stop dings already.
# [2023-11-14 18:08:22.239437] No improvement in 100 steps
# Step = 4485 loss = 0.000002 normalized loss line= -248.765151x+26895.170733. There was 8 stop dings already.
# [2023-11-14 18:08:46.855450] No improvement in 100 steps
# Step = 4856 loss = 0.000750 normalized loss line= 0.132155x+-4.242150. There was 9 stop dings already.
# [2023-11-14 18:08:53.893217] No improvement in 100 steps
# Step = 4956 loss = 0.000001 normalized loss line= -676.779520x+46852.962089. There was 10 stop dings already.
# [2023-11-14 18:08:57.268718] Print every 1000 step
# Step = 5000 loss = 0.000001 normalized loss line= -681.261712x+47163.261031. There was 11 stop dings already.
# [2023-11-14 18:09:15.070258] No improvement in 100 steps
# Step = 5288 loss = 0.000009 normalized loss line= -0.000037x+0.150829. There was 11 stop dings already.
# Using explicitly sent system of equations.
# dimensionality is 1
# grid.shape is (320,)
# Shape of the grid for solver torch.Size([320, 1])
# Grid is  <class 'torch.Tensor'> torch.Size([320, 1])
# torch.Size([1])
# [2023-11-14 18:09:15.441627] initial (min) loss is 175.03643798828125
# [2023-11-14 18:09:15.517989] Print every 1000 step
# Step = 0 loss = 175.036438 normalized loss line= 0.000000x+1.000000. There was 1 stop dings already.
# [2023-11-14 18:10:14.313047] Print every 1000 step
# Step = 1000 loss = 0.000202 normalized loss line= 0.019071x+1.198750. There was 1 stop dings already.
# [2023-11-14 18:10:31.908432] No improvement in 100 steps
# Step = 1333 loss = 0.000107 normalized loss line= 0.148743x+-2.409830. There was 1 stop dings already.
# [2023-11-14 18:10:45.574686] No improvement in 100 steps
# Step = 1556 loss = 0.000042 normalized loss line= 0.279454x+-6.757078. There was 2 stop dings already.
# [2023-11-14 18:10:50.860889] No improvement in 100 steps
# Step = 1656 loss = 0.113138 normalized loss line= 0.000044x+0.000412. There was 3 stop dings already.
# [2023-11-14 18:10:55.941093] No improvement in 100 steps
# Step = 1756 loss = 0.000842 normalized loss line= 0.683303x+11.214085. There was 4 stop dings already.
# [2023-11-14 18:11:03.924597] No improvement in 100 steps
# Step = 1916 loss = 0.000356 normalized loss line= 0.036625x+-0.501665. There was 5 stop dings already.
# [2023-11-14 18:11:08.501179] Print every 1000 step
# Step = 2000 loss = 0.000277 normalized loss line= 0.047202x+-0.646543. There was 6 stop dings already.
# [2023-11-14 18:11:09.554189] No improvement in 100 steps
# Step = 2016 loss = 0.000136 normalized loss line= -5.254225x+651.782446. There was 6 stop dings already.
# [2023-11-14 18:11:15.842899] No improvement in 100 steps
# Step = 2116 loss = 0.000080 normalized loss line= 0.134951x+-2.770295. There was 7 stop dings already.
# [2023-11-14 18:11:22.512964] No improvement in 100 steps
# Step = 2216 loss = 0.000043 normalized loss line= 0.049508x+2.186418. There was 8 stop dings already.
# [2023-11-14 18:11:28.416175] No improvement in 100 steps
# Step = 2316 loss = 0.001886 normalized loss line= 0.861456x+-20.754095. There was 9 stop dings already.
# [2023-11-14 18:11:38.766688] No improvement in 100 steps
# Step = 2511 loss = 0.000328 normalized loss line= 0.013546x+0.149713. There was 10 stop dings already.
# [2023-11-14 18:11:44.024433] No improvement in 100 steps
# Step = 2611 loss = 0.009041 normalized loss line= 0.156716x+-3.643825. There was 11 stop dings already.

# %%
mae_compl_3_5 = np.mean(np.abs((pred_u_compl_3_5 - x_test)/x_test))
mae_compl_5 = np.mean(np.abs((pred_u_compl_5 - x_test)/x_test))
mae_compl_2_5 = np.mean(np.abs((pred_u_compl_2_5 - x_test)/x_test))

print(f'MAPE on the test dataset for eq with $C = 3.5$ is {mae_compl_3_5}')
print(f'MAPE on the test dataset for eq with $C = 5$ is {mae_compl_5}')
print(f'MAPE on the test dataset for eq with $C = 4$ is {mae_compl_2_5}')

plt.plot(t_test, pred_u_compl_5, color = 'b', label = 'Automatic solution of the equation, $C = 5$')
plt.plot(t_test, pred_u_compl_3_5, color = 'magenta', label = 'Automatic solution of the equation, $C = 3.5$')
plt.plot(t_test, pred_u_compl_2_5, color = 'seagreen', label = 'Automatic solution of the equation, $C = 2.5$')

plt.plot(t_test[::3], x_test[::3], '*', color = 'r', label = 'Referential data')
plt.grid()
plt.legend(loc = 'lower left')
plt.show()
# Out:
# MAPE on the test dataset for eq with $C = 3.5$ is 0.9981632434643799
# MAPE on the test dataset for eq with $C = 5$ is 0.03557201854479851
# MAPE on the test dataset for eq with $C = 4$ is 0.39093209717733757

# %% [markdown]
# Here, we can notice, that the "correct" governing equation, which closely matches the Van der Pol equation, has the lowest MAPE metric on the test dataset, even outperforming the equations with higher complexities. The equation with lower complexity can represent only the averaged values of the system. Thus, we can select the equation like $u'' = -u + 0.2 u' - 0.2 u^2 u' + \delta$ for system representation.

# %% [markdown]
# ## Lotka-Volterra system

# %%
def Lotka_Volterra_by_RK(initial : tuple, timestep : float, steps : int, alpha : float, 
                         beta : float, delta : float, gamma : float):
    res = np.full(shape = (steps, 2), fill_value = initial, dtype=np.float64)
    for step in range(steps-1):
        # print(res[step, :])
        k1 = alpha * res[step, 0] - beta * res[step, 0] * res[step, 1]; x1 = res[step, 0] + timestep/2. * k1
        l1 = delta * res[step, 0] * res[step, 1] - gamma * res[step, 1]; y1 = res[step, 1] + timestep/2. * l1

        k2 = alpha * x1 - beta * x1 * y1; x2 = res[step, 0] + timestep/2. * k2
        l2 = delta * x1 * y1 - gamma * y1; y2 = res[step, 1] + timestep/2. * l2

        k3 = alpha * x2 - beta * x2 * y2
        l3 = delta * x2 * y2 - gamma * y1
        
        x3 = res[step, 0] + timestep * k1 - 2 * timestep * k2 + 2 * timestep * k3
        y3 = res[step, 1] + timestep * l1 - 2 * timestep * l2 + 2 * timestep * l3
        k4 = alpha * x3 - beta * x3 * y3
        l4 = delta * x3 * y3 - gamma * y3
        
        res[step+1, 0] = res[step, 0] + timestep / 6. * (k1 + 2 * k2 + 2 * k3 + k4)
        res[step+1, 1] = res[step, 1] + timestep / 6. * (l1 + 2 * l2 + 2 * l3 + l4)
    return res

steps_num = 301; step = 1./steps_num
t = np.arange(start = 0, stop = step * steps_num, step = step)
solution = Lotka_Volterra_by_RK(initial=(4., 2.), timestep=step, steps=steps_num, 
                                alpha=20., beta=20., delta=20., gamma=20.)

# %%
def epde_discovery(t, x, y, use_ann = False):
    dimensionality = x.ndim - 1
    
    '''
    Подбираем Парето-множество систем дифф. уравнений.
    '''
    epde_search_obj = epde.EpdeSearch(use_solver = False, dimensionality = dimensionality, 
                                          boundary = 25, coordinate_tensors = [t,])
    
    if use_ann:
        epde_search_obj.set_preprocessor(default_preprocessor_type='ANN',
                                         preprocessor_kwargs={'epochs_max' : 25000})
    else:
        epde_search_obj.set_preprocessor(default_preprocessor_type='poly',
                                         preprocessor_kwargs={'use_smoothing' : True, 'sigma' : 1, 
                                                              'polynomial_window' : 3, 'poly_order' : 3})
    
    popsize = 20
    epde_search_obj.set_moeadd_params(population_size = popsize, training_epochs=30)

    factors_max_number = {'factors_num' : [1, 2], 'probas' : [0.5, 0.5]}
    
    epde_search_obj.fit(data=[x, y], variable_names=['u', 'v'], max_deriv_order=(1,),
                        equation_terms_max_number=5, data_fun_pow = 2,
                        equation_factors_max_number=factors_max_number,
                        eq_sparsity_interval=(1e-8, 1e-4))       
    return epde_search_obj

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))
ax1.plot(t, solution[:, 0], color= 'k', label = 'Prey')
ax1.plot(t, solution[:, 1], color= 'r', label = 'Hunters')
ax1.set_xlabel('Time')
ax1.set_ylabel('Population size')
ax1.legend(loc = 'upper right')
ax1.grid()

ax2.set_xlabel('Prey')
ax2.set_ylabel('Hunters')
ax2.plot(solution[:, 0], solution[:, 1], color= 'k')
ax2.grid()
plt.show()

# %%
t_max = 150
t_train = t[:t_max]; t_test = t[t_max:]

x = solution[:t_max, 0]; x_test = solution[t_max:, 0]
y = solution[:t_max, 1]; y_test = solution[t_max:, 1]

epde_search_obj = epde_discovery(t_train, x, y, False)
epde_search_obj.equations(only_print = True, num = 1)
# Out:
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7f06b1ef60d0>
# setting builder with <epde.optimizers.builder.StrategyBuilder object at 0x7f06b1ef60d0>
# Deriv orders after definition [[None], [0]]
# 150
# initial_shape (150,) derivs_tensor.shape (150, 1)
# self.tokens is ['u', 'du/dx0']
# Here, derivs order is {'u': [None], 'du/dx0': [0]}
# Deriv orders after definition [[None], [0]]
# 150
# initial_shape (150,) derivs_tensor.shape (150, 1)
# self.tokens is ['v', 'dv/dx0']
# Here, derivs order is {'v': [None], 'dv/dx0': [0]}
# The cardinality of defined token pool is [2 2]
# Among them, the pool contains [2 2]
# Creating new equation, sparsity value [1.60777933e-07 1.16300063e-06]
# New solution accepted, confirmed 1/20 solutions.
# Creating new equation, sparsity value [5.01694093e-08 1.56636522e-05]
# New solution accepted, confirmed 2/20 solutions.
# Creating new equation, sparsity value [2.57337456e-06 1.03269306e-07]
# New solution accepted, confirmed 3/20 solutions.
# Creating new equation, sparsity value [1.10755721e-07 1.68167730e-05]
# New solution accepted, confirmed 4/20 solutions.
# Creating new equation, sparsity value [3.57977985e-06 1.03916718e-08]
# New solution accepted, confirmed 5/20 solutions.
# Creating new equation, sparsity value [2.89107974e-08 1.01555630e-08]
# New solution accepted, confirmed 6/20 solutions.
# Creating new equation, sparsity value [1.43546837e-08 5.84208522e-05]
# New solution accepted, confirmed 7/20 solutions.
# Creating new equation, sparsity value [1.53038535e-07 2.53319423e-08]
# New solution accepted, confirmed 8/20 solutions.
# Creating new equation, sparsity value [2.31913702e-08 1.03116049e-08]
# New solution accepted, confirmed 9/20 solutions.
# Creating new equation, sparsity value [5.03624942e-07 6.21519306e-08]
# New solution accepted, confirmed 10/20 solutions.
# Creating new equation, sparsity value [5.38436267e-05 2.60641570e-07]
# New solution accepted, confirmed 11/20 solutions.
# Creating new equation, sparsity value [1.05637641e-08 1.04281009e-06]
# New solution accepted, confirmed 12/20 solutions.
# Creating new equation, sparsity value [3.53426233e-05 1.24794275e-07]
# New solution accepted, confirmed 13/20 solutions.
# Creating new equation, sparsity value [6.80633692e-05 4.72860847e-05]
# New solution accepted, confirmed 14/20 solutions.
# Creating new equation, sparsity value [3.07245125e-08 4.74891094e-08]
# New solution accepted, confirmed 15/20 solutions.
# Creating new equation, sparsity value [3.78115284e-05 5.63334347e-07]
# New solution accepted, confirmed 16/20 solutions.
# Creating new equation, sparsity value [7.87692764e-06 1.77951627e-05]
# New solution accepted, confirmed 17/20 solutions.
# Creating new equation, sparsity value [1.84692069e-05 2.02143163e-05]
# New solution accepted, confirmed 18/20 solutions.
# Creating new equation, sparsity value [3.29083297e-05 6.80034030e-08]
# New solution accepted, confirmed 19/20 solutions.
# Creating new equation, sparsity value [5.9483379e-07 8.3347470e-05]
# New solution accepted, confirmed 20/20 solutions.
# best_obj 4
# Multiobjective optimization : 0-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 1-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 2-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 3-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 4-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 5-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 6-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 7-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 8-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 9-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 10-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 11-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 12-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 13-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 14-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 15-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 16-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 17-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 18-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 19-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 20-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 21-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 22-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 23-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 24-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 25-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 26-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 27-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 28-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# Multiobjective optimization : 29-th epoch.
# During MO : processing 0-th weight.
# During MO : processing 1-th weight.
# During MO : processing 2-th weight.
# During MO : processing 3-th weight.
# During MO : processing 4-th weight.
# During MO : processing 5-th weight.
# During MO : processing 6-th weight.
# During MO : processing 7-th weight.
# During MO : processing 8-th weight.
# During MO : processing 9-th weight.
# During MO : processing 10-th weight.
# During MO : processing 11-th weight.
# During MO : processing 12-th weight.
# During MO : processing 13-th weight.
# During MO : processing 14-th weight.
# During MO : processing 15-th weight.
# During MO : processing 16-th weight.
# During MO : processing 17-th weight.
# During MO : processing 18-th weight.
# During MO : processing 19-th weight.
# The optimization has been conducted.
#
#
# 0-th non-dominated level
#
#
#  / 19.934665931511315 * u{power: 1.0} + 0.0 * dv/dx0{power: 1.0} + -0.039250718569721954 * v{power: 1.0} + -20.041375260025056 * u{power: 1.0} * v{power: 1.0} + 0.04478234563292395 = du/dx0{power: 1.0}
#  \ -20.01798775115551 * v{power: 1.0} + 0.0 * v{power: 2.0} + 0.0 * v{power: 1.0} * dv/dx0{power: 1.0} + 20.09289859841227 * v{power: 1.0} * u{power: 1.0} + 0.015835971200209704 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0018807183789317334}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0005964201944372705}} , with objective function values of [0.54377449 0.62301301 3.         2.5       ]
#
#  / 20.007177440857625 * u{power: 1.0} + -1.002235276221399 * dv/dx0{power: 1.0} + -20.042462702333484 * v{power: 1.0} + 0.0 * v{power: 1.0} * dv/dx0{power: 1.0} + 0.0014214474687071197 = du/dx0{power: 1.0}
#  \ -0.9977695784097712 * du/dx0{power: 1.0} + -19.997760825712497 * v{power: 1.0} + 19.962554237986755 * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + 0.001417372220154486 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0008344437629019929}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0009801489763148809}} , with objective function values of [0.02153993 0.02149118 3.         3.        ]
#
#  / -1.0022352762213975 * dv/dx0{power: 1.0} + 20.007177440857618 * u{power: 1.0} + -20.042462702333474 * v{power: 1.0} + 0.0 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + 0.0014214474687006444 = du/dx0{power: 1.0}
#  \ -0.997769578409771 * du/dx0{power: 1.0} + 19.962554237986744 * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + -19.9977608257125 * v{power: 1.0} + 0.0014173722201550546 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0023749681967899176}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0024646171539382256}} , with objective function values of [0.02153993 0.02149118 3.         3.        ]
#
#  / 0.0 * v{power: 2.0} + 19.944063302462535 * u{power: 1.0} + -20.058099508000648 * v{power: 1.0} * u{power: 1.0} + 0.0 * dv/dx0{power: 1.0} + 0.026957388649261015 = du/dx0{power: 1.0}
#  \ -19.997760825712515 * v{power: 1.0} + -0.9977695784097703 * du/dx0{power: 1.0} + 0.0 * du/dx0{power: 1.0} * v{power: 1.0} + 19.96255423798674 * u{power: 1.0} + 0.0014173722201140345 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0010410040508936531}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.00043346269725387065}} , with objective function values of [0.55268966 0.02149118 2.5        3.        ]
#
#  / 0.0 * dv/dx0{power: 1.0} + 19.944063302462535 * u{power: 1.0} + 0.0 * v{power: 1.0} + -20.058099508000648 * v{power: 1.0} * u{power: 1.0} + 0.026957388649261015 = du/dx0{power: 1.0}
#  \ -19.99776082571248 * v{power: 1.0} + 0.0 * v{power: 1.0} * du/dx0{power: 1.0} + 19.96255423798675 * u{power: 1.0} + -0.9977695784097704 * du/dx0{power: 1.0} + 0.0014173722200938542 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.004475458196381203}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0030136964238481386}} , with objective function values of [0.55268966 0.02149118 2.5        3.        ]
#
#  / 0.0 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + 0.0 * dv/dx0{power: 1.0} + 19.944063302462535 * u{power: 1.0} + -20.058099508000648 * u{power: 1.0} * v{power: 1.0} + 0.026957388649261015 = du/dx0{power: 1.0}
#  \ -0.997769578409771 * du/dx0{power: 1.0} + 0.0 * du/dx0{power: 2.0} + 19.962554237986744 * u{power: 1.0} + -19.9977608257125 * v{power: 1.0} + 0.0014173722201550546 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0019655498887379014}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0018042706643646327}} , with objective function values of [0.55268966 0.02149118 2.5        3.        ]
#
#  / 20.007177440857586 * u{power: 1.0} + -20.04246270233348 * v{power: 1.0} + -1.0022352762213989 * dv/dx0{power: 1.0} + 0.0 * du/dx0{power: 1.0} * v{power: 1.0} + 0.0014214474687060427 = du/dx0{power: 1.0}
#  \ -0.9977695784097712 * du/dx0{power: 1.0} + -19.997760825712497 * v{power: 1.0} + 0.0 * v{power: 2.0} + 19.962554237986755 * u{power: 1.0} + 0.001417372220154486 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.000874835471445324}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0001284962635761523}} , with objective function values of [0.02153993 0.02149118 3.         3.        ]
#
#  / 0.0 * u{power: 2.0} + 19.944063302462535 * u{power: 1.0} + 0.0 * dv/dx0{power: 1.0} + -20.058099508000648 * u{power: 1.0} * v{power: 1.0} + 0.026957388649261015 = du/dx0{power: 1.0}
#  \ -19.99776082571248 * v{power: 1.0} + 19.96255423798675 * u{power: 1.0} + -0.9977695784097704 * du/dx0{power: 1.0} + 0.0 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + 0.0014173722200938542 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.005351742517493436}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.002641641278939211}} , with objective function values of [0.55268966 0.02149118 2.5        3.        ]
#
#  / -0.0033069127476721286 * du/dx0{power: 1.0} * u{power: 1.0} + 20.13088152076356 * u{power: 1.0} + 0.0 * dv/dx0{power: 1.0} + -20.21218273417861 * u{power: 1.0} * v{power: 1.0} + -0.013246152623087683 = du/dx0{power: 1.0}
#  \ -20.01798775115551 * v{power: 1.0} + 0.0 * v{power: 2.0} + 0.0 * dv/dx0{power: 1.0} * du/dx0{power: 1.0} + 20.09289859841227 * v{power: 1.0} * u{power: 1.0} + 0.015835971200209704 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0039676527171058}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.004465352580382188}} , with objective function values of [0.3793452  0.62301301 4.         2.5       ]
#
#  / -0.00012975664263295637 * u{power: 1.0} * du/dx0{power: 1.0} + -20.04697653551628 * v{power: 1.0} + 20.01514640077724 * u{power: 1.0} + -1.0025919041561493 * dv/dx0{power: 1.0} + -0.0013506556396821706 = du/dx0{power: 1.0}
#  \ -0.0001294814546955374 * du/dx0{power: 1.0} * u{power: 1.0} + 19.96340278751075 * u{power: 1.0} + -0.997414557144014 * du/dx0{power: 1.0} + -19.995149037302337 * v{power: 1.0} + -0.0013489643314360034 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.008064341560247944}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.00917352116578859}} , with objective function values of [0.01652049 0.01647852 4.5        4.5       ]
#
#  / -20.058099508000616 * u{power: 1.0} * v{power: 1.0} + 0.0 * v{power: 1.0} + 19.94406330246251 * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + 0.026957388649257886 = du/dx0{power: 1.0}
#  \ 0.0 * du/dx0{power: 2.0} + 20.092898598412276 * v{power: 1.0} * u{power: 1.0} + -20.0179877511555 * v{power: 1.0} + 0.0 * v{power: 1.0} * dv/dx0{power: 1.0} + 0.015835971200211428 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.002334661577461085}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0009686918047946602}} , with objective function values of [0.55268966 0.62301301 2.5        2.5       ]
#
#  / 20.010118440792166 * u{power: 1.0} + -1.003046951147713 * dv/dx0{power: 1.0} + -20.064939975066714 * v{power: 1.0} + 1.4978817263067952e-05 * dv/dx0{power: 2.0} + 0.0016647352875839353 = du/dx0{power: 1.0}
#  \ 19.99673862757093 * v{power: 1.0} * u{power: 1.0} + -19.95863066487399 * v{power: 1.0} + 0.07232096507480569 * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * v{power: 1.0} + -0.04324308962812302 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0056971762777664305}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0009223542432188685}} , with objective function values of [0.00960333 0.52142281 5.         3.        ]
#
#  / 0.0 * u{power: 2.0} + 19.944063302462535 * u{power: 1.0} + 0.0 * dv/dx0{power: 1.0} + -20.058099508000648 * u{power: 1.0} * v{power: 1.0} + 0.026957388649261015 = du/dx0{power: 1.0}
#  \ -0.997769578409771 * du/dx0{power: 1.0} + 19.962554237986744 * u{power: 1.0} + -19.9977608257125 * v{power: 1.0} + 0.0 * du/dx0{power: 2.0} + 0.0014173722201550546 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.004686999199188761}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.00556025687934612}} , with objective function values of [0.55268966 0.02149118 2.5        3.        ]
#
#  / -20.04246270233349 * v{power: 1.0} + -1.0022352762213975 * dv/dx0{power: 1.0} + 20.007177440857625 * u{power: 1.0} + 0.0 * v{power: 2.0} + 0.0014214474687115918 = du/dx0{power: 1.0}
#  \ 19.962554237986726 * u{power: 1.0} + -0.9977695784097689 * du/dx0{power: 1.0} + -19.997760825712522 * v{power: 1.0} + 0.0 * du/dx0{power: 2.0} + 0.001417372220105367 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.004899355698756864}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0007405065817610468}} , with objective function values of [0.02153993 0.02149118 3.         3.        ]
#
#  / -20.046976535516425 * v{power: 1.0} + 20.015146400777414 * u{power: 1.0} + -1.0025919041561524 * dv/dx0{power: 1.0} + -0.00012975664263402306 * u{power: 1.0} * du/dx0{power: 1.0} + -0.001350655639670435 = du/dx0{power: 1.0}
#  \ 0.0 * du/dx0{power: 2.0} + 3.9921366140219288 * u{power: 2.0} + -22.256976343152694 * v{power: 1.0} + -0.5520577086169188 * du/dx0{power: 1.0} + 4.149510067734354 = dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.0021259528141179714}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.005160511038836887}} , with objective function values of [1.65204851e-02 2.38765435e+01 4.50000000e+00 3.50000000e+00]
#
#  / 0.0 * v{power: 2.0} + 0.0 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + 0.0 * u{power: 1.0} * v{power: 1.0} + 2.5930428928603866 * u{power: 1.0} + -0.46944238188988846 = du/dx0{power: 1.0} * v{power: 1.0}
#  \ -0.6569437793646106 * du/dx0{power: 1.0} * u{power: 1.0} + -0.01794111390614947 * dv/dx0{power: 2.0} + 35.615314506900866 * u{power: 1.0} + 0.005018909219973895 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + -13.368803143090492 = dv/dx0{power: 1.0} * v{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.004152605024345027}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.00022306334890431697}} , with objective function values of [23.32656294 75.36324685  2.          7.5       ]
#
#  / 0.0 * du/dx0{power: 1.0} + 2.5930428928603866 * u{power: 1.0} + 0.0 * u{power: 1.0} * dv/dx0{power: 1.0} + 0.0 * v{power: 1.0} * u{power: 1.0} + -0.46944238188988846 = du/dx0{power: 1.0} * v{power: 1.0}
#  \ -0.2847433338951778 * dv/dx0{power: 2.0} + 316.58088171755503 * v{power: 1.0} + 229.35306429938586 * u{power: 1.0} + 0.0 * dv/dx0{power: 1.0} * v{power: 1.0} + -178.53701636819886 = du/dx0{power: 1.0} * dv/dx0{power: 1.0}
# {'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.004069214107351997}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0027900471368253604}} , with objective function values of [  23.32656294 1261.33367973    2.            5.        ]

# %%
disc_eq = epde_search_obj.get_equations_by_complexity([2.5, 2.5])[0]

# %%
disc_eq.text_form
# Out:
# " / -20.058099508000616 * u{power: 1.0} * v{power: 1.0} + 0.0 * v{power: 1.0} + 19.94406330246251 * u{power: 1.0} + 0.0 * du/dx0{power: 1.0} * dv/dx0{power: 1.0} + 0.026957388649257886 = du/dx0{power: 1.0}\n \\ 0.0 * du/dx0{power: 2.0} + 20.092898598412276 * v{power: 1.0} * u{power: 1.0} + -20.0179877511555 * v{power: 1.0} + 0.0 * v{power: 1.0} * dv/dx0{power: 1.0} + 0.015835971200211428 = dv/dx0{power: 1.0}\n{'terms_number': {'optimizable': False, 'value': 5}, 'max_factors_in_term': {'optimizable': False, 'value': {'factors_num': [1, 2], 'probas': [0.5, 0.5]}}, ('sparsity', 'u'): {'optimizable': True, 'value': 0.002334661577461085}, ('sparsity', 'v'): {'optimizable': True, 'value': 0.0009686918047946602}}"

# %%
pred_u_v = epde_search_obj.predict(system=disc_eq, boundary_conditions=None, mode='mat') # , boundary_conditions=[bop_x(), bop_y()], 
                                   #grid = [t_pred,], strategy=SOLVER_STRATEGY
# Out:
# Using explicitly sent system of equations.
# dimensionality is 1
# grid.shape is (150,)
# Shape of the grid for solver torch.Size([1, 150])
# [torch.Size([1, 1]), torch.Size([1, 1])]
# [torch.Size([1, 1]), torch.Size([1, 1])]
# Grid is  <class 'torch.Tensor'> torch.Size([1, 150])
# torch.Size([150])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-e9dde15cc465> in <module>
# ----> 1 pred_u_v = epde_search_obj.predict(system=disc_eq, boundary_conditions=None, mode='mat') # , boundary_conditions=[bop_x(), bop_y()],
#       2                                    #grid = [t_pred,], strategy=SOLVER_STRATEGY
#
# ~/epde/EPDE_main/epde/interface/interface.py in predict(self, system, boundary_conditions, grid, data, system_file, solver_kwargs, mode)
#     846         print(f'grid.shape is {grid[0].shape}')
#     847         print(f'Shape of the grid for solver {adapter.convert_grid(grid, mode = mode).shape}')
# --> 848         solution_model = adapter.solve_epde_system(system = system, grids = grid, data = data,
#     849                                                    boundary_conditions = boundary_conditions, mode = mode)
#     850         return solution_model(adapter.convert_grid(grid, mode = mode)).detach().numpy()
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in solve_epde_system(self, system, grids, boundary_conditions, mode, data)
#     497                           boundary_conditions=boundary_conditions, mode = mode)
#     498
# --> 499     @staticmethod
#     500     def convert_grid(grid, mode):
#     501         assert isinstance(grid, (list, tuple)), 'Convertion of the tensor can be only held from tuple or list.'
#
# ~/epde/EPDE_main/epde/interface/solver_integration.py in solve(self, system_form, grid, boundary_conditions, mode)
#
# ~/epde/EPDE_main/epde/solver/solver.py in solve(self, lambda_operator, lambda_bound, derivative_points, lambda_update, second_order_interactions, sampling_N, verbose, learning_rate, gamma, lr_decay, eps, tmin, tmax, nmodels, name, abs_loss, use_cache, cache_dir, cache_verbose, save_always, print_every, cache_model, patience, loss_oscillation_window, no_improvement_patience, model_randomize_parameter, optimizer_mode, step_plot_print, step_plot_save, image_save_dir, tol, clear_cache, normalized_loss_stop, inverse_parameters)
#     306                                       lambda_operator, lambda_bound, tol, derivative_points)
#     307
# --> 308             min_loss , _ = Solution_class.evaluate()
#     309
#     310         self.plot = Plots(self.model, self.grid, self.mode, tol)
#
# ~/epde/EPDE_main/epde/solver/solution.py in evaluate(self, second_order_interactions, sampling_N, lambda_update, save_graph)
#      87         """
#      88
# ---> 89         op = self.operator.operator_compute()
#      90         bval, true_bval, bval_keys, bval_length = self.boundary.apply_bcs()
#      91
#
# ~/epde/EPDE_main/epde/solver/eval.py in operator_compute(self)
#     178     def operator_compute(self):
#     179         if self.weak_form == None or self.weak_form == []:
# --> 180             return self.pde_compute()
#     181         else:
#     182             return self.weak_pde_compute(self.weak_form)
#
# ~/epde/EPDE_main/epde/solver/eval.py in pde_compute(self)
#     140             op_list = []
#     141             for i in range(num_of_eq):
# --> 142                 op_list.append(self.apply_operator(
#     143                     self.prepared_operator[i], self.sorted_grid).reshape(-1,1))
#     144             op = torch.cat(op_list, 1)
#
# ~/epde/EPDE_main/epde/solver/eval.py in apply_operator(self, operator, grid_points)
#     118         for term in operator:
#     119             term = operator[term]
# --> 120             dif = derivative(term, grid_points)
#     121             try:
#     122                 total += dif
#
# ~/epde/EPDE_main/epde/solver/derivative.py in take_derivative(self, term, grid_points)
#     250         der_term = torch.zeros_like(self.model) + 1
#     251         for j, scheme in enumerate(term[dif_dir]):
# --> 252             prod=self.model[term['var'][j]]
#     253             if scheme!=[None]:
#     254                 for axis in scheme:
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
plt.plot(t_train, x, '+', label = 'preys, odeint')
plt.plot(t_train, y, '*', label = "predators, odeint")
plt.plot(t_train, pred_u_v[:, 0], color = 'b', label='preys, NN')
plt.plot(t_train, pred_u_v[:, 1], color = 'r', label='predators, NN')
plt.xlabel('Time t, [days]')
plt.ylabel('Population')
plt.grid()
plt.legend(loc='upper right')
plt.show()
